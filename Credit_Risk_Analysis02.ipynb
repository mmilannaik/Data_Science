# %% [markdown]
# <a href="https://colab.research.google.com/github/mmilannaik/Data_Science/blob/master/Credit_Risk_Analysis_from_Real_Life_Scenario.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES
# TO THE CORRECT LOCATION (/kaggle/input) IN YOUR NOTEBOOK,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.

import os
import sys
from tempfile import NamedTemporaryFile
from urllib.request import urlopen
from urllib.parse import unquote, urlparse
from urllib.error import HTTPError
from zipfile import ZipFile
import tarfile
import shutil

CHUNK_SIZE = 40960
DATA_SOURCE_MAPPING = 'credit-risk-dataset:https%3A%2F%2Fstorage.googleapis.com%2Fkaggle-data-sets%2F1404394%2F2327131%2Fbundle%2Farchive.zip%3FX-Goog-Algorithm%3DGOOG4-RSA-SHA256%26X-Goog-Credential%3Dgcp-kaggle-com%2540kaggle-161607.iam.gserviceaccount.com%252F20240706%252Fauto%252Fstorage%252Fgoog4_request%26X-Goog-Date%3D20240706T061906Z%26X-Goog-Expires%3D259200%26X-Goog-SignedHeaders%3Dhost%26X-Goog-Signature%...'

KAGGLE_INPUT_PATH='/kaggle/input'
KAGGLE_WORKING_PATH='/kaggle/working'
KAGGLE_SYMLINK='kaggle'

# !umount /kaggle/input/ 2> /dev/null
shutil.rmtree('/kaggle/input', ignore_errors=True)
os.makedirs(KAGGLE_INPUT_PATH, 0o777, exist_ok=True)
os.makedirs(KAGGLE_WORKING_PATH, 0o777, exist_ok=True)

try:
  os.symlink(KAGGLE_INPUT_PATH, os.path.join("..", 'input'), target_is_directory=True)
except FileExistsError:
  pass
try:
  os.symlink(KAGGLE_WORKING_PATH, os.path.join("..", 'working'), target_is_directory=True)
except FileExistsError:
  pass

for data_source_mapping in DATA_SOURCE_MAPPING.split(','):
    directory, download_url_encoded = data_source_mapping.split(':')
    download_url = unquote(download_url_encoded)
    filename = urlparse(download_url).path
    destination_path = os.path.join(KAGGLE_INPUT_PATH, directory)
    try:
        with urlopen(download_url) as fileres, NamedTemporaryFile() as tfile:
            total_length = fileres.headers['content-length']
            print(f'Downloading {directory}, {total_length} bytes compressed')
            dl = 0
            data = fileres.read(CHUNK_SIZE)
            while len(data) > 0:
                dl += len(data)
                tfile.write(data)
                done = int(50 * dl / int(total_length))
                sys.stdout.write(f"\r[{'=' * done}{' ' * (50-done)}] {dl} bytes downloaded")
                sys.stdout.flush()
                data = fileres.read(CHUNK_SIZE)
            if filename.endswith('.zip'):
              with ZipFile(tfile) as zfile:
                zfile.extractall(destination_path)
            else:
              with tarfile.open(tfile.name) as tarfile:
                tarfile.extractall(destination_path)
            print(f'\nDownloaded and uncompressed: {directory}')
    except HTTPError as e:
        print(f'Failed to load (likely expired) {download_url} to path {destination_path}')
        continue
    except OSError as e:
        print(f'Failed to load {download_url} to path {destination_path}')
        continue

print('Data source import complete.')
# Out:
# Downloading credit-risk-dataset, 106142650 bytes compressed
# [==================================================] 106142650 bytes downloaded
# Downloaded and uncompressed: credit-risk-dataset
# Data source import complete.

# %% [markdown]
# <head><center><font size=6><b>
#     Credit Risk Analysis
#     </b></font></center></head>
# <body><font size=3><p style="text-align: justify;">
#     Credit risk analysis is an essential step in the credit granting process of financial institutions. Its purpose is to assess creditworthiness and identify the potential risks associated with lending. This notebook will discuss the steps and methodologies used in credit risk analysis, as well as the factors that need to be considered to make informed credit decisions.
#     </font></body>
# <center><img src="https://static.vecteezy.com/system/resources/previews/001/373/061/non_2x/hand-holding-credit-card-top-view-free-photo.jpg" width="511" height="338">

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import re

import warnings
warnings.filterwarnings("ignore")

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder, OrdinalEncoder
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score, confusion_matrix

# %%
# Importing our data
df = pd.read_csv("/kaggle/input/credit-risk-dataset/loan/loan.csv",index_col=0)

# %%
pd.options.display.max_columns = None

# %% [markdown]
# ## 1. Data Understanding
# ### 1.1 Summary :
# - The dataset has 887,379 rows and 73 columns.
# - There are 50 numerical columns and 23 categorical columns.
# - Approximately 20 columns have missing values greater than 70%.
# - The average budgeted amount is nearly equal to the amount borrowed.
# - The average loan interest rate is 13.24%, which is quite large
# - There are 5 columns in date format, which are 'issue_d', 'last_pymnt_d','next_pymnt_d' earliest_cr_line', and last_credit_pull_d'.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 887379 entries, 1077501 to 36271262
# Data columns (total 73 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   member_id                    887379 non-null  int64
#  1   loan_amnt                    887379 non-null  float64
#  2   funded_amnt                  887379 non-null  float64
#  3   funded_amnt_inv              887379 non-null  float64
#  4   term                         887379 non-null  object
#  5   int_rate                     887379 non-null  float64
#  6   installment                  887379 non-null  float64
#  7   grade                        887379 non-null  object
#  8   sub_grade                    887379 non-null  object
#  9   emp_title                    835917 non-null  object
#  10  emp_length                   842554 non-null  object
#  11  home_ownership               887379 non-null  object
#  12  annual_inc                   887375 non-null  float64
#  13  verification_status          887379 non-null  object
#  14  issue_d                      887379 non-null  object
#  15  loan_status                  887379 non-null  object
#  16  pymnt_plan                   887379 non-null  object
#  17  url                          887379 non-null  object
#  18  desc                         126026 non-null  object
#  19  purpose                      887379 non-null  object
#  20  title                        887226 non-null  object
#  21  zip_code                     887379 non-null  object
#  22  addr_state                   887379 non-null  object
#  23  dti                          887379 non-null  float64
#  24  delinq_2yrs                  887350 non-null  float64
#  25  earliest_cr_line             887350 non-null  object
#  26  inq_last_6mths               887350 non-null  float64
#  27  mths_since_last_delinq       433067 non-null  float64
#  28  mths_since_last_record       137053 non-null  float64
#  29  open_acc                     887350 non-null  float64
#  30  pub_rec                      887350 non-null  float64
#  31  revol_bal                    887379 non-null  float64
#  32  revol_util                   886877 non-null  float64
#  33  total_acc                    887350 non-null  float64
#  34  initial_list_status          887379 non-null  object
#  35  out_prncp                    887379 non-null  float64
#  36  out_prncp_inv                887379 non-null  float64
#  37  total_pymnt                  887379 non-null  float64
#  38  total_pymnt_inv              887379 non-null  float64
#  39  total_rec_prncp              887379 non-null  float64
#  40  total_rec_int                887379 non-null  float64
#  41  total_rec_late_fee           887379 non-null  float64
#  42  recoveries                   887379 non-null  float64
#  43  collection_recovery_fee      887379 non-null  float64
#  44  last_pymnt_d                 869720 non-null  object
#  45  last_pymnt_amnt              887379 non-null  float64
#  46  next_pymnt_d                 634408 non-null  object
#  47  last_credit_pull_d           887326 non-null  object
#  48  collections_12_mths_ex_med   887234 non-null  float64
#  49  mths_since_last_major_derog  221703 non-null  float64
#  50  policy_code                  887379 non-null  float64
#  51  application_type             887379 non-null  object
#  52  annual_inc_joint             511 non-null     float64
#  53  dti_joint                    509 non-null     float64
#  54  verification_status_joint    511 non-null     object
#  55  acc_now_delinq               887350 non-null  float64
#  56  tot_coll_amt                 817103 non-null  float64
#  57  tot_cur_bal                  817103 non-null  float64
#  58  open_acc_6m                  21372 non-null   float64
#  59  open_il_6m                   21372 non-null   float64
#  60  open_il_12m                  21372 non-null   float64
#  61  open_il_24m                  21372 non-null   float64
#  62  mths_since_rcnt_il           20810 non-null   float64
#  63  total_bal_il                 21372 non-null   float64
#  64  il_util                      18617 non-null   float64
#  65  open_rv_12m                  21372 non-null   float64
#  66  open_rv_24m                  21372 non-null   float64
#  67  max_bal_bc                   21372 non-null   float64
#  68  all_util                     21372 non-null   float64
#  69  total_rev_hi_lim             817103 non-null  float64
#  70  inq_fi                       21372 non-null   float64
#  71  total_cu_tl                  21372 non-null   float64
#  72  inq_last_12m                 21372 non-null   float64
# dtypes: float64(49), int64(1), object(23)
# memory usage: 501.0+ MB

# %%
df.describe()
# Out:
#           member_id      loan_amnt    funded_amnt  funded_amnt_inv  \
# count  8.873790e+05  887379.000000  887379.000000    887379.000000
# mean   3.500182e+07   14755.264605   14741.877625     14702.464383
# std    2.411335e+07    8435.455601    8429.897657      8442.106732
# min    7.047300e+04     500.000000     500.000000         0.000000
# 25%    1.087713e+07    8000.000000    8000.000000      8000.000000
# 50%    3.709528e+07   13000.000000   13000.000000     13000.000000
# 75%    5.847135e+07   20000.000000   20000.000000     20000.000000
# max    7.354484e+07   35000.000000   35000.000000     35000.000000
#
#             int_rate    installment    annual_inc            dti  \
# count  887379.000000  887379.000000  8.873750e+05  887379.000000
# mean       13.246740     436.717127  7.502759e+04      18.157039
# std         4.381867     244.186593  6.469830e+04      17.190626
# min         5.320000      15.670000  0.000000e+00       0.000000
# 25%         9.990000     260.705000  4.500000e+04      11.910000
# 50%        12.990000     382.550000  6.500000e+04      17.650000
# 75%        16.200000     572.600000  9.000000e+04      23.950000
# max        28.990000    1445.460000  9.500000e+06    9999.000000
#
#          delinq_2yrs  inq_last_6mths  mths_since_last_delinq  \
# count  887350.000000   887350.000000           433067.000000
# mean        0.314442        0.694623               34.063798
# std         0.862244        0.998448               21.884940
# min         0.000000        0.000000                0.000000
# 25%         0.000000        0.000000               15.000000
# 50%         0.000000        0.000000               31.000000
# 75%         0.000000        1.000000               50.000000
# max        39.000000       33.000000              188.000000
#
#        mths_since_last_record       open_acc        pub_rec     revol_bal  \
# count           137053.000000  887350.000000  887350.000000  8.873790e+05
# mean                70.117903      11.548469       0.195307  1.692079e+04
# std                 28.127914       5.317313       0.582091  2.242679e+04
# min                  0.000000       0.000000       0.000000  0.000000e+00
# 25%                 51.000000       8.000000       0.000000  6.443000e+03
# 50%                 70.000000      11.000000       0.000000  1.187500e+04
# 75%                 92.000000      14.000000       0.000000  2.082900e+04
# max                129.000000      90.000000      86.000000  2.904836e+06
#
#           revol_util      total_acc      out_prncp  out_prncp_inv  \
# count  886877.000000  887350.000000  887379.000000  887379.000000
# mean       55.067693      25.268026    8403.124852    8399.713242
# std        23.834344      11.840561    8493.450269    8489.997617
# min         0.000000       1.000000       0.000000       0.000000
# 25%        37.700000      17.000000       0.000000       0.000000
# 50%        56.000000      24.000000    6458.290000    6455.810000
# 75%        73.600000      32.000000   13659.055000   13654.050000
# max       892.300000     169.000000   49372.860000   49372.860000
#
#          total_pymnt  total_pymnt_inv  total_rec_prncp  total_rec_int  \
# count  887379.000000    887379.000000    887379.000000  887379.000000
# mean     7558.826684      7521.160306      5757.706424    1754.804327
# std      7871.243336      7846.108604      6625.441046    2095.356099
# min         0.000000         0.000000         0.000000       0.000000
# 25%      1914.590000      1899.700000      1200.570000     441.460000
# 50%      4894.999117      4862.010000      3215.320000    1073.280000
# 75%     10616.814231     10565.690000      8000.000000    2238.265000
# max     57777.579870     57777.580000     35000.030000   24205.620000
#
#        total_rec_late_fee     recoveries  collection_recovery_fee  \
# count       887379.000000  887379.000000            887379.000000
# mean             0.396692      45.919243                 4.880757
# std              4.087825     409.693874                63.125281
# min              0.000000       0.000000                 0.000000
# 25%              0.000000       0.000000                 0.000000
# 50%              0.000000       0.000000                 0.000000
# 75%              0.000000       0.000000                 0.000000
# max            358.680000   33520.270000              7002.190000
#
#        last_pymnt_amnt  collections_12_mths_ex_med  \
# count    887379.000000               887234.000000
# mean       2164.145585                    0.014380
# std        4794.783233                    0.134191
# min           0.000000                    0.000000
# 25%         280.170000                    0.000000
# 50%         462.780000                    0.000000
# 75%         831.245000                    0.000000
# max       36475.590000                   20.000000
#
#        mths_since_last_major_derog  policy_code  annual_inc_joint   dti_joint  \
# count                221703.000000     887379.0        511.000000  509.000000
# mean                     44.104838          1.0     109981.011585   18.310118
# std                      22.179841          0.0      52730.379847    7.169233
# min                       0.000000          1.0      17950.000000    3.000000
# 25%                      27.000000          1.0      76032.500000   13.200000
# 50%                      44.000000          1.0     101771.000000   17.610000
# 75%                      61.000000          1.0     132800.000000   22.650000
# max                     188.000000          1.0     500000.000000   43.860000
#
#        acc_now_delinq  tot_coll_amt   tot_cur_bal   open_acc_6m    open_il_6m  \
# count   887350.000000  8.171030e+05  8.171030e+05  21372.000000  21372.000000
# mean         0.004991  2.257026e+02  1.394582e+05      1.109021      2.928832
# std          0.077625  1.031137e+04  1.537500e+05      1.242675      3.089987
# min          0.000000  0.000000e+00  0.000000e+00      0.000000      0.000000
# 25%          0.000000  0.000000e+00  2.985300e+04      0.000000      1.000000
# 50%          0.000000  0.000000e+00  8.055900e+04      1.000000      2.000000
# 75%          0.000000  0.000000e+00  2.082050e+05      2.000000      4.000000
# max         14.000000  9.152545e+06  8.000078e+06     14.000000     40.000000
#
#         open_il_12m   open_il_24m  mths_since_rcnt_il   total_bal_il  \
# count  21372.000000  21372.000000        20810.000000   21372.000000
# mean       0.761651      1.674574           20.912686   36552.811389
# std        0.996035      1.688725           27.209081   43103.833619
# min        0.000000      0.000000            0.000000       0.000000
# 25%        0.000000      0.000000            6.000000   10251.500000
# 50%        0.000000      1.000000           12.000000   24684.500000
# 75%        1.000000      2.000000           23.000000   47858.000000
# max       12.000000     19.000000          363.000000  878459.000000
#
#             il_util   open_rv_12m   open_rv_24m     max_bal_bc      all_util  \
# count  18617.000000  21372.000000  21372.000000   21372.000000  21372.000000
# mean      71.535317      1.389060      2.975482    5887.979740     60.831939
# std       23.022862      1.520129      2.631886    5284.701239     20.013254
# min        0.000000      0.000000      0.000000       0.000000      0.000000
# 25%       58.600000      0.000000      1.000000    2411.000000     47.700000
# 50%       74.900000      1.000000      2.000000    4483.000000     61.900000
# 75%       87.600000      2.000000      4.000000    7771.500000     75.200000
# max      223.300000     22.000000     43.000000  127305.000000    151.400000
#
#        total_rev_hi_lim        inq_fi   total_cu_tl  inq_last_12m
# count      8.171030e+05  21372.000000  21372.000000  21372.000000
# mean       3.206862e+04      0.943945      1.537058      1.977307
# std        3.749826e+04      1.446872      2.723339      2.874067
# min        0.000000e+00      0.000000      0.000000     -4.000000
# 25%        1.390000e+04      0.000000      0.000000      0.000000
# 50%        2.370000e+04      0.000000      0.000000      2.000000
# 75%        3.980000e+04      1.000000      2.000000      3.000000
# max        9.999999e+06     17.000000     35.000000     32.000000

# %%
df.head(3)
# Out:
#          member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# id
# 1077501    1296599     5000.0       5000.0           4975.0   36 months
# 1077430    1314167     2500.0       2500.0           2500.0   60 months
# 1077175    1313524     2400.0       2400.0           2400.0   36 months
#
#          int_rate  installment grade sub_grade emp_title emp_length  \
# id
# 1077501     10.65       162.87     B        B2       NaN  10+ years
# 1077430     15.27        59.83     C        C4     Ryder   < 1 year
# 1077175     15.96        84.33     C        C5       NaN  10+ years
#
#         home_ownership  annual_inc verification_status   issue_d  loan_status  \
# id
# 1077501           RENT     24000.0            Verified  Dec-2011   Fully Paid
# 1077430           RENT     30000.0     Source Verified  Dec-2011  Charged Off
# 1077175           RENT     12252.0        Not Verified  Dec-2011   Fully Paid
#
#         pymnt_plan                                                url  \
# id
# 1077501          n  https://www.lendingclub.com/browse/loanDetail....
# 1077430          n  https://www.lendingclub.com/browse/loanDetail....
# 1077175          n  https://www.lendingclub.com/browse/loanDetail....
#
#                                                       desc         purpose  \
# id
# 1077501    Borrower added on 12/22/11 > I need to upgra...     credit_card
# 1077430    Borrower added on 12/22/11 > I plan to use t...             car
# 1077175                                                NaN  small_business
#
#                         title zip_code addr_state    dti  delinq_2yrs  \
# id
# 1077501              Computer    860xx         AZ  27.65          0.0
# 1077430                  bike    309xx         GA   1.00          0.0
# 1077175  real estate business    606xx         IL   8.72          0.0
#
#         earliest_cr_line  inq_last_6mths  mths_since_last_delinq  \
# id
# 1077501         Jan-1985             1.0                     NaN
# 1077430         Apr-1999             5.0                     NaN
# 1077175         Nov-2001             2.0                     NaN
#
#          mths_since_last_record  open_acc  pub_rec  revol_bal  revol_util  \
# id
# 1077501                     NaN       3.0      0.0    13648.0        83.7
# 1077430                     NaN       3.0      0.0     1687.0         9.4
# 1077175                     NaN       2.0      0.0     2956.0        98.5
#
#          total_acc initial_list_status  out_prncp  out_prncp_inv  total_pymnt  \
# id
# 1077501        9.0                   f        0.0            0.0  5861.071414
# 1077430        4.0                   f        0.0            0.0  1008.710000
# 1077175       10.0                   f        0.0            0.0  3003.653644
#
#          total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  \
# id
# 1077501          5831.78          5000.00         861.07                 0.0
# 1077430          1008.71           456.46         435.17                 0.0
# 1077175          3003.65          2400.00         603.65                 0.0
#
#          recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt  \
# id
# 1077501        0.00                     0.00     Jan-2015           171.62
# 1077430      117.08                     1.11     Apr-2013           119.66
# 1077175        0.00                     0.00     Jun-2014           649.91
#
#         next_pymnt_d last_credit_pull_d  collections_12_mths_ex_med  \
# id
# 1077501          NaN           Jan-2016                         0.0
# 1077430          NaN           Sep-2013                         0.0
# 1077175          NaN           Jan-2016                         0.0
#
#          mths_since_last_major_derog  policy_code application_type  \
# id
# 1077501                          NaN          1.0       INDIVIDUAL
# 1077430                          NaN          1.0       INDIVIDUAL
# 1077175                          NaN          1.0       INDIVIDUAL
#
#          annual_inc_joint  dti_joint verification_status_joint  \
# id
# 1077501               NaN        NaN                       NaN
# 1077430               NaN        NaN                       NaN
# 1077175               NaN        NaN                       NaN
#
#          acc_now_delinq  tot_coll_amt  tot_cur_bal  open_acc_6m  open_il_6m  \
# id
# 1077501             0.0           NaN          NaN          NaN         NaN
# 1077430             0.0           NaN          NaN          NaN         NaN
# 1077175             0.0           NaN          NaN          NaN         NaN
#
#          open_il_12m  open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  \
# id
# 1077501          NaN          NaN                 NaN           NaN      NaN
# 1077430          NaN          NaN                 NaN           NaN      NaN
# 1077175          NaN          NaN                 NaN           NaN      NaN
#
#          open_rv_12m  open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  \
# id
# 1077501          NaN          NaN         NaN       NaN               NaN
# 1077430          NaN          NaN         NaN       NaN               NaN
# 1077175          NaN          NaN         NaN       NaN               NaN
#
#          inq_fi  total_cu_tl  inq_last_12m
# id
# 1077501     NaN          NaN           NaN
# 1077430     NaN          NaN           NaN
# 1077175     NaN          NaN           NaN

# %%
# Check missing values in the dataset
missing_values_per_column = (df.isnull().sum() / len(df)) * 100
columns_to_drop = missing_values_per_column[missing_values_per_column > 70].index
columns_to_drop
# Out:
# Index(['desc', 'mths_since_last_record', 'mths_since_last_major_derog',
#        'annual_inc_joint', 'dti_joint', 'verification_status_joint',
#        'open_acc_6m', 'open_il_6m', 'open_il_12m', 'open_il_24m',
#        'mths_since_rcnt_il', 'total_bal_il', 'il_util', 'open_rv_12m',
#        'open_rv_24m', 'max_bal_bc', 'all_util', 'inq_fi', 'total_cu_tl',
#        'inq_last_12m'],
#       dtype='object')

# %%
filtered_data = df.drop(columns_to_drop,axis=1)

# %%
categorical_data = filtered_data.select_dtypes(include=['object'])
categorical_data.head(3)
# Out:
#                term grade sub_grade emp_title emp_length home_ownership  \
# id
# 1077501   36 months     B        B2       NaN  10+ years           RENT
# 1077430   60 months     C        C4     Ryder   < 1 year           RENT
# 1077175   36 months     C        C5       NaN  10+ years           RENT
#
#         verification_status   issue_d  loan_status pymnt_plan  \
# id
# 1077501            Verified  Dec-2011   Fully Paid          n
# 1077430     Source Verified  Dec-2011  Charged Off          n
# 1077175        Not Verified  Dec-2011   Fully Paid          n
#
#                                                        url         purpose  \
# id
# 1077501  https://www.lendingclub.com/browse/loanDetail....     credit_card
# 1077430  https://www.lendingclub.com/browse/loanDetail....             car
# 1077175  https://www.lendingclub.com/browse/loanDetail....  small_business
#
#                         title zip_code addr_state earliest_cr_line  \
# id
# 1077501              Computer    860xx         AZ         Jan-1985
# 1077430                  bike    309xx         GA         Apr-1999
# 1077175  real estate business    606xx         IL         Nov-2001
#
#         initial_list_status last_pymnt_d next_pymnt_d last_credit_pull_d  \
# id
# 1077501                   f     Jan-2015          NaN           Jan-2016
# 1077430                   f     Apr-2013          NaN           Sep-2013
# 1077175                   f     Jun-2014          NaN           Jan-2016
#
#         application_type
# id
# 1077501       INDIVIDUAL
# 1077430       INDIVIDUAL
# 1077175       INDIVIDUAL

# %%
categorical_data.nunique()
# Out:
# term                        2
# grade                       7
# sub_grade                  35
# emp_title              299271
# emp_length                 11
# home_ownership              6
# verification_status         3
# issue_d                   103
# loan_status                10
# pymnt_plan                  2
# url                    887379
# purpose                    14
# title                   63143
# zip_code                  935
# addr_state                 51
# earliest_cr_line          697
# initial_list_status         2
# last_pymnt_d               98
# next_pymnt_d              100
# last_credit_pull_d        103
# application_type            2
# dtype: int64

# %%
# Columns that have too many unique values will be dropped
cat_drop = ['url','emp_title','title','zip_code','sub_grade']
categorical_data.drop(cat_drop,axis=1,inplace=True)
categorical_data.head(3)
# Out:
#                term grade emp_length home_ownership verification_status  \
# id
# 1077501   36 months     B  10+ years           RENT            Verified
# 1077430   60 months     C   < 1 year           RENT     Source Verified
# 1077175   36 months     C  10+ years           RENT        Not Verified
#
#           issue_d  loan_status pymnt_plan         purpose addr_state  \
# id
# 1077501  Dec-2011   Fully Paid          n     credit_card         AZ
# 1077430  Dec-2011  Charged Off          n             car         GA
# 1077175  Dec-2011   Fully Paid          n  small_business         IL
#
#         earliest_cr_line initial_list_status last_pymnt_d next_pymnt_d  \
# id
# 1077501         Jan-1985                   f     Jan-2015          NaN
# 1077430         Apr-1999                   f     Apr-2013          NaN
# 1077175         Nov-2001                   f     Jun-2014          NaN
#
#         last_credit_pull_d application_type
# id
# 1077501           Jan-2016       INDIVIDUAL
# 1077430           Sep-2013       INDIVIDUAL
# 1077175           Jan-2016       INDIVIDUAL

# %%
numerical_data = filtered_data.select_dtypes(include=['int64','float64'])
numerical_data.head(3)
# Out:
#          member_id  loan_amnt  funded_amnt  funded_amnt_inv  int_rate  \
# id
# 1077501    1296599     5000.0       5000.0           4975.0     10.65
# 1077430    1314167     2500.0       2500.0           2500.0     15.27
# 1077175    1313524     2400.0       2400.0           2400.0     15.96
#
#          installment  annual_inc    dti  delinq_2yrs  inq_last_6mths  \
# id
# 1077501       162.87     24000.0  27.65          0.0             1.0
# 1077430        59.83     30000.0   1.00          0.0             5.0
# 1077175        84.33     12252.0   8.72          0.0             2.0
#
#          mths_since_last_delinq  open_acc  pub_rec  revol_bal  revol_util  \
# id
# 1077501                     NaN       3.0      0.0    13648.0        83.7
# 1077430                     NaN       3.0      0.0     1687.0         9.4
# 1077175                     NaN       2.0      0.0     2956.0        98.5
#
#          total_acc  out_prncp  out_prncp_inv  total_pymnt  total_pymnt_inv  \
# id
# 1077501        9.0        0.0            0.0  5861.071414          5831.78
# 1077430        4.0        0.0            0.0  1008.710000          1008.71
# 1077175       10.0        0.0            0.0  3003.653644          3003.65
#
#          total_rec_prncp  total_rec_int  total_rec_late_fee  recoveries  \
# id
# 1077501          5000.00         861.07                 0.0        0.00
# 1077430           456.46         435.17                 0.0      117.08
# 1077175          2400.00         603.65                 0.0        0.00
#
#          collection_recovery_fee  last_pymnt_amnt  collections_12_mths_ex_med  \
# id
# 1077501                     0.00           171.62                         0.0
# 1077430                     1.11           119.66                         0.0
# 1077175                     0.00           649.91                         0.0
#
#          policy_code  acc_now_delinq  tot_coll_amt  tot_cur_bal  \
# id
# 1077501          1.0             0.0           NaN          NaN
# 1077430          1.0             0.0           NaN          NaN
# 1077175          1.0             0.0           NaN          NaN
#
#          total_rev_hi_lim
# id
# 1077501               NaN
# 1077430               NaN
# 1077175               NaN

# %%
# since member_id is the identity for each entry and policy code only has one value, these column are removed
numerical_data.drop(['member_id','policy_code'],axis=1,inplace=True)

# %%
new_df = pd.concat([numerical_data,categorical_data],axis=1)

# %% [markdown]
# ### 1.2 Bad Borrower vs Good Borrower
# ##### Good Borrowers:
#
# - Fully Paid: These borrowers have completely repaid their loans on time. This indicates a good credit history and responsible borrowing behavior.
# - Current: These borrowers are currently making their loan payments on time. While not a complete repayment yet, it shows they are meeting their current obligations.
# - In Grace Period: Borrowers in the grace period are slightly late on their payments but typically have a short window (around 15 days) to catch up without penalty. This might be due to a temporary setback and doesn't necessarily reflect poorly on their creditworthiness.
#
# ##### Bad Borrowers:
#
# - Charged Off: The lender has written off the loan as a loss because the borrower is unlikely to repay it. This is a severe delinquency and indicates a high credit risk.
# - Default: The borrower has failed to make their loan payments for a certain period (usually 90 days or more). This is a serious delinquency that can significantly damage a borrower's credit score.
# - Late (16-30 days) / Late (31-120 days): These borrowers are late on their repayments by varying degrees. Even a single late payment can negatively impact their credit score, and habitual late payments are a sign of potential credit problems.
# - Does not meet the credit policy. Status: Fully Paid / Does not meet the credit policy. Status: Charged Off: These borrowers did not meet the lender's creditworthiness standards when initially issued the loan but eventually repaid it (Fully Paid) or defaulted (Charged Off). Despite the eventual repayment (Fully Paid), not meeting the credit policy initially suggests a higher credit risk.
# - Issued: The loan status is simply "Issued" and doesn't provide enough information to determine the borrower's repayment behavior. It's best to exclude this category until there's a history of repayments.

# %%
new_df['loan_status'].unique()
# Out:
# array(['Fully Paid', 'Charged Off', 'Current', 'Default',
#        'Late (31-120 days)', 'In Grace Period', 'Late (16-30 days)',
#        'Does not meet the credit policy. Status:Fully Paid',
#        'Does not meet the credit policy. Status:Charged Off', 'Issued'],
#       dtype=object)

# %%
# Define the mapping for desired values (1 for good status, 0 for others)
mapping = {'Fully Paid': 1, 'Current': 1, 'In Grace Period': 1,
           'Charged Off': 0, 'Default': 0, 'Late (31-120 days)': 0,
           'Late (16-30 days)': 0,
           'Does not meet the credit policy. Status:Fully Paid': 0,
           'Does not meet the credit policy. Status:Charged Off': 0,
           'Issued': 0}
# Create a new column for the transformed data
new_df['loan_status'] = new_df['loan_status'].replace(mapping)

# %% [markdown]
# ### 1.3 Detecting Outlier
# - As many as 27 of the 31 numerical columns have outliers above the upper whisker.
# - The distribution is heavily skewed to the left, indicating that most of the values are concentrated in the lower range. Consider transforming the data to reduce skewness
# - In the 'dti' and 'revol_util' columns there are outliers that are significantly different from other data. It is possible that this is an error value so consider deleting it.

# %%
def detect_outlier(column_name):
    Q1 = df[column_name].quantile(0.25)
    Q3 = df[column_name].quantile(0.75)
    IQR = Q3 - Q1
    lower_whisker = Q1 - 1.5 * IQR
    upper_whisker = Q3 + 1.5 * IQR
    for entry in df[column_name]:
        if entry > upper_whisker or entry < lower_whisker :
            return 'YES'
    return 'NO'

# %%
numerical_cols = new_df.select_dtypes(include=['int64','float64'])
numerical_cols = numerical_cols.drop('loan_status',axis=1) # exclude target variable
outlier_cols = []
for col in numerical_cols.columns:
    if detect_outlier(col)=='YES':
        outlier_cols.append(col)

# %%
# Find columns with outliers
outlier_cols
# Out:
# ['int_rate',
#  'installment',
#  'annual_inc',
#  'dti',
#  'delinq_2yrs',
#  'inq_last_6mths',
#  'mths_since_last_delinq',
#  'open_acc',
#  'pub_rec',
#  'revol_bal',
#  'revol_util',
#  'total_acc',
#  'out_prncp',
#  'out_prncp_inv',
#  'total_pymnt',
#  'total_pymnt_inv',
#  'total_rec_prncp',
#  'total_rec_int',
#  'total_rec_late_fee',
#  'recoveries',
#  'collection_recovery_fee',
#  'last_pymnt_amnt',
#  'collections_12_mths_ex_med',
#  'acc_now_delinq',
#  'tot_coll_amt',
#  'tot_cur_bal',
#  'total_rev_hi_lim']

# %%
fig, axes = plt.subplots(nrows=9, ncols=3, figsize=(20, 30))
for i, ax in enumerate(axes.flat):
    if i < len(outlier_cols):
        column_name = outlier_cols[i]
        sns.boxplot(y=column_name, data=new_df, ax=ax)
        ax.set_title(column_name)
plt.tight_layout()

# %%
fig, axes = plt.subplots(nrows=9, ncols=3, figsize=(20, 30))
for i, ax in enumerate(axes.flat):
    if i < len(outlier_cols):
        column_name = outlier_cols[i]
        sns.histplot(x=column_name, data=new_df, ax=ax)
        ax.set_title(column_name)
plt.tight_layout()

# %%
# Delete error value in 'dti'
new_df.drop(new_df[new_df['dti'] > 8000].index, inplace=True)

# %%
# Delete error value in 'revol_util'
new_df.drop(new_df[new_df['revol_util'] > 300].index, inplace=True)

# %% [markdown]
# #### 1.4 Exploratory Data Analysis
# - The bar chart shows that people who borrow for education, small businesses, or weddings who have larger than average revolving balances have a higher risk.
# - The average monthly payments that borrowers must pay appear to be higher for lower classes. However, they have the same risk tendencies.
# - Most loan funds are spread across California, Texas, New York, and Florida.
# - The total amount committed by high-risk borrowers is less than the amount applied for a loan.

# %%
sns.barplot(
    x="revol_bal",y="purpose",
    hue="loan_status", data=new_df,
    width=0.7 ,dodge=True,
    orient='h'
)
plt.xticks(rotation=90)
plt.grid()
plt.tight_layout()

# %%
sns.barplot(
    x='grade',y='installment', hue='loan_status',
    data=new_df, order=['A','B','C','D','E','F','G']
)
plt.grid()

# %%
plt.figure(figsize=(10,10))
sns.barplot(
    x='addr_state',y='loan_amnt',
    estimator='sum', data=new_df,
    width=0.8, dodge=True
)
plt.xticks(rotation=90)
plt.grid()
plt.tight_layout()

# %%
plt.figure(figsize=(6,6))
sns.scatterplot(x='loan_amnt',y='total_pymnt',hue='loan_status',data=new_df)
# Out:
# <Axes: xlabel='loan_amnt', ylabel='total_pymnt'>

# %%
corr_df = new_df.select_dtypes(include=['int','float']).corr()
plt.figure(figsize=(8,8))
sns.heatmap(corr_df,vmin=-1,vmax=1,cmap='jet')
# Out:
# <Axes: >

# %% [markdown]
# Some features have high correlation. These features can cause overfitting in the model. To prevent this from happening, one of the feature pairs is removed from the dataset

# %%
upper = corr_df.abs().where(np.triu(np.ones(corr_df.shape), k=1).astype(np.bool_))
to_drop_hicorr = [column for column in upper.columns if any(upper[column] > 0.7)]

# %%
to_drop_hicorr
# Out:
# ['funded_amnt',
#  'funded_amnt_inv',
#  'installment',
#  'out_prncp_inv',
#  'total_pymnt_inv',
#  'total_rec_prncp',
#  'collection_recovery_fee',
#  'last_pymnt_amnt',
#  'total_rev_hi_lim']

# %%
new_df.drop(to_drop_hicorr, axis=1, inplace=True)

# %% [markdown]
# ## 2. Data Preparation

# %% [markdown]
# ### 2.1 Data Formatting
# - Data that should be numeric but in the dataframe is in string form because it has units is changed to just numbers by removing the units, ex: '36 months' -> 36

# %%
new_df['term'] = new_df['term'].str.replace(r"[^\d+]", "", regex=True)
new_df['term'] = pd.to_numeric(new_df['term'], errors='coerce')
new_df['term'].astype(int)
# Out:
# id
# 1077501     36
# 1077430     60
# 1077175     36
# 1076863     36
# 1075358     60
#             ..
# 36371250    36
# 36441262    36
# 36271333    60
# 36490806    60
# 36271262    36
# Name: term, Length: 887375, dtype: int64

# %%
new_df['emp_length'] = new_df['emp_length'].replace(to_replace='10+ years',value=10)
new_df['emp_length'] = new_df['emp_length'].replace(to_replace='< 1 year',value=0)
new_df['emp_length'] = new_df['emp_length'].replace(to_replace='.years',value='',regex=True)
new_df['emp_length'] = new_df['emp_length'].replace(to_replace='.year',value='',regex=True)
new_df['emp_length'].astype('float')
# Out:
# id
# 1077501     10.0
# 1077430      0.0
# 1077175     10.0
# 1076863     10.0
# 1075358      1.0
#             ...
# 36371250     8.0
# 36441262    10.0
# 36271333     5.0
# 36490806     1.0
# 36271262    10.0
# Name: emp_length, Length: 887375, dtype: float64

# %% [markdown]
# ### 2.2 Train Test Split

# %%
X = new_df.drop('loan_status',axis=1)
y = new_df['loan_status']
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=42,stratify=y)

# %% [markdown]
# ### 2.3 Imputation

# %%
num_cols = X.select_dtypes(include=['int','float']).columns # Numerical columns
cat_cols = X.select_dtypes(include='object').columns # Categorical columns

# %%
num_cols
# Out:
# Index(['loan_amnt', 'int_rate', 'annual_inc', 'dti', 'delinq_2yrs',
#        'inq_last_6mths', 'mths_since_last_delinq', 'open_acc', 'pub_rec',
#        'revol_bal', 'revol_util', 'total_acc', 'out_prncp', 'total_pymnt',
#        'total_rec_int', 'total_rec_late_fee', 'recoveries',
#        'collections_12_mths_ex_med', 'acc_now_delinq', 'tot_coll_amt',
#        'tot_cur_bal', 'term'],
#       dtype='object')

# %%
X[num_cols].isnull().sum()
# Out:
# loan_amnt                          0
# int_rate                           0
# annual_inc                         4
# dti                                0
# delinq_2yrs                       29
# inq_last_6mths                    29
# mths_since_last_delinq        454310
# open_acc                          29
# pub_rec                           29
# revol_bal                          0
# revol_util                       502
# total_acc                         29
# out_prncp                          0
# total_pymnt                        0
# total_rec_int                      0
# total_rec_late_fee                 0
# recoveries                         0
# collections_12_mths_ex_med       145
# acc_now_delinq                    29
# tot_coll_amt                   70276
# tot_cur_bal                    70276
# term                               0
# dtype: int64

# %%
num_cols = X.select_dtypes(include=['int','float']).columns # Numerical columns
cat_cols = X.select_dtypes(include='object').columns # Categorical columns

# Impute missing values in numerical features (using median strategy)
imputer_numerical = SimpleImputer(strategy='median')
imputer_numerical.fit(X_train[num_cols])
X_train[num_cols] = imputer_numerical.transform(X_train[num_cols])
X_test[num_cols] = imputer_numerical.transform(X_test[num_cols])

# Impute missing values in categorical features (using most_frequent strategy)
imputer_categorical = SimpleImputer(strategy='most_frequent')
imputer_categorical.fit(X_train[cat_cols])
X_train[cat_cols] = imputer_categorical.transform(X_train[cat_cols])
X_test[cat_cols] = imputer_categorical.transform(X_test[cat_cols])

# %% [markdown]
# Now we have X_train and X_test with imputed missing values for both numerical and categorical features

# %% [markdown]
# ### 2.3 Parsing Dates

# %%
X_train[cat_cols].head()
# Out:
#          grade emp_length home_ownership verification_status   issue_d  \
# id
# 16422685     C         10            OWN            Verified  May-2014
# 42415296     D         10       MORTGAGE            Verified  Mar-2015
# 36230330     E         10            OWN            Verified  Dec-2014
# 36491278     C          0       MORTGAGE        Not Verified  Dec-2014
# 40979481     A          6       MORTGAGE     Source Verified  Feb-2015
#
#          pymnt_plan             purpose addr_state earliest_cr_line  \
# id
# 16422685          n               house         OR         Oct-1980
# 42415296          n  debt_consolidation         AZ         Jan-2000
# 36230330          n    home_improvement         CA         Sep-1981
# 36491278          n  debt_consolidation         MD         Oct-1993
# 40979481          n  debt_consolidation         CA         Mar-1982
#
#          initial_list_status last_pymnt_d next_pymnt_d last_credit_pull_d  \
# id
# 16422685                   f     Apr-2015     Feb-2016           Jan-2016
# 42415296                   f     Jan-2016     Feb-2016           Jan-2016
# 36230330                   w     Jan-2016     Feb-2016           Dec-2015
# 36491278                   f     Aug-2015     Feb-2016           Aug-2015
# 40979481                   w     Jan-2016     Feb-2016           Jan-2016
#
#          application_type
# id
# 16422685       INDIVIDUAL
# 42415296       INDIVIDUAL
# 36230330       INDIVIDUAL
# 36491278       INDIVIDUAL
# 40979481       INDIVIDUAL

# %% [markdown]
# Some columns have values in the form of dates. However, Python does not know that the data is a date but an object

# %%
date_cols = ['issue_d','earliest_cr_line','last_pymnt_d','next_pymnt_d','last_credit_pull_d']
for col in date_cols:
    X_train[col] = pd.to_datetime(X_train[col], format='%b-%Y')
    X_test[col] = pd.to_datetime(X_test[col], format='%b-%Y')

# %%
X_train[date_cols]
# Out:
#             issue_d earliest_cr_line last_pymnt_d next_pymnt_d  \
# id
# 16422685 2014-05-01       1980-10-01   2015-04-01   2016-02-01
# 42415296 2015-03-01       2000-01-01   2016-01-01   2016-02-01
# 36230330 2014-12-01       1981-09-01   2016-01-01   2016-02-01
# 36491278 2014-12-01       1993-10-01   2015-08-01   2016-02-01
# 40979481 2015-02-01       1982-03-01   2016-01-01   2016-02-01
# ...             ...              ...          ...          ...
# 7926703  2013-10-01       2007-05-01   2014-07-01   2016-02-01
# 30295800 2014-10-01       2000-08-01   2016-01-01   2016-02-01
# 65673300 2015-11-01       1995-10-01   2016-01-01   2016-02-01
# 35034269 2014-11-01       2000-08-01   2016-01-01   2016-02-01
# 55209019 2015-08-01       1998-08-01   2016-01-01   2016-02-01
#
#          last_credit_pull_d
# id
# 16422685         2016-01-01
# 42415296         2016-01-01
# 36230330         2015-12-01
# 36491278         2015-08-01
# 40979481         2016-01-01
# ...                     ...
# 7926703          2014-12-01
# 30295800         2016-01-01
# 65673300         2016-01-01
# 35034269         2016-01-01
# 55209019         2016-01-01
#
# [665531 rows x 5 columns]

# %% [markdown]
# The 'last_pymnt_d' column and the 'last_credit_pull_d' column seem appear to have many of the same dates. Let's check the correlation of these columns. If it is more than 70%, consider to remove one of them.

# %%
X_train[['last_pymnt_d','last_credit_pull_d']].corr()
# Out:
#                     last_pymnt_d  last_credit_pull_d
# last_pymnt_d            1.000000            0.730067
# last_credit_pull_d      0.730067            1.000000

# %%
X_train.drop('last_credit_pull_d',axis=1,inplace=True)
X_test.drop('last_credit_pull_d',axis=1,inplace=True)

# %% [markdown]
# Due to machine learning model that will be used require numerical value, all not numerical value need to convert to numerical value. In this instance, all event dates must be changed to reflect the issue date.

# %%
X_train['earliest_cr_line_D'] = X_train['issue_d'] - X_train['earliest_cr_line']
X_test['earliest_cr_line_D'] = X_test['issue_d'] - X_test['earliest_cr_line']

X_train['last_pymnt_d_D'] = X_train['last_pymnt_d'] - X_train['issue_d']
X_test['last_pymnt_d_D'] = X_test['last_pymnt_d'] - X_test['issue_d']

X_train['next_pymnt_d_D'] = X_train['next_pymnt_d'] - X_train['issue_d']
X_test['next_pymnt_d_D'] = X_test['next_pymnt_d'] - X_test['issue_d']

# %%
X_train.drop(X_train.select_dtypes(include='datetime').columns,axis=1,inplace=True)
X_test.drop(X_test.select_dtypes(include='datetime').columns,axis=1,inplace=True)

# %%
# convert timedelta datatype into integer datatype
time_delta_cols = X_train.select_dtypes(include='timedelta').columns
for col in time_delta_cols:
    X_train[col] = X_train[col].dt.days
    X_test[col] = X_test[col].dt.days

# %% [markdown]
# ### 2.4 Encoding

# %%
cat_cols = X_train.select_dtypes(include='object').columns
X_train[cat_cols].nunique()
# Out:
# grade                   7
# emp_length             11
# home_ownership          6
# verification_status     3
# pymnt_plan              2
# purpose                14
# addr_state             51
# initial_list_status     2
# application_type        2
# dtype: int64

# %%
col_to_check = [
    'home_ownership','verification_status',
    'pymnt_plan','initial_list_status',
    'application_type'
]
for col in col_to_check:
    print(X_train[col].value_counts())
    print('')
# Out:
# home_ownership
# MORTGAGE    333140
# RENT        266726
# OWN          65480
# OTHER          144
# NONE            39
# ANY              2
# Name: count, dtype: int64
#
# verification_status
# Source Verified    247381
# Verified           218308
# Not Verified       199842
# Name: count, dtype: int64
#
# pymnt_plan
# n    665522
# y         9
# Name: count, dtype: int64
#
# initial_list_status
# f    342837
# w    322694
# Name: count, dtype: int64
#
# application_type
# INDIVIDUAL    665152
# JOINT            379
# Name: count, dtype: int64

# %% [markdown]
# - The 'grade' column is encoded with OrdinalEncoder because it is multilevel data.
# - The 'purpose','addr_state', and 'home_ownership' column is encoded with LabelEncoder
# - The 'application_type' column and the 'pymnt_plan' column are considered for deletion because they are dominated by only one value.
# - Meanwhile, the other columns are simply encoded with OneHotEncoder.

# %%
X_train.drop(['application_type','pymnt_plan'],axis=1,inplace=True)
X_test.drop(['application_type','pymnt_plan'],axis=1,inplace=True)

# %% [markdown]
# If there are values in the test data that are not present in the training data, the encoder will generate an error. We must therefore check them. We can move on to the next stage as long as there are no columns that are stuck.

# %%
cat_cols = X_train.select_dtypes(include='object').columns
good_label_cols = [col for col in cat_cols if set(X_test[col]).issubset(set(X_train[col]))]
bad_label_cols = list(set(cat_cols)-set(good_label_cols))
bad_label_cols
# Out:
# []

# %%
# Ordinal Encoder
ordinal_enc = OrdinalEncoder()
X_train['grade_enc'] = ordinal_enc.fit_transform(X_train[['grade']])
X_test['grade_enc'] = ordinal_enc.transform(X_test[['grade']])

# %%
# Label Encoder
label_enc = LabelEncoder()
X_train['home_ownership_enc'] = label_enc.fit_transform(X_train[['home_ownership']])
X_test['home_ownership_enc'] = label_enc.transform(X_test[['home_ownership']])
X_train['purpose_enc'] = label_enc.fit_transform(X_train[['purpose']])
X_test['purpose_enc'] = label_enc.transform(X_test[['purpose']])
X_train['addr_state_enc'] = label_enc.fit_transform(X_train[['addr_state']])
X_test['addr_state_enc'] = label_enc.transform(X_test[['addr_state']])

# %%
# One-Hot Encoder
one_hot_enc = OneHotEncoder(sparse=False)
initial_list_status_train = pd.DataFrame(one_hot_enc.fit_transform(X_train[['initial_list_status']]),columns=one_hot_enc.get_feature_names_out())
initial_list_status_test = pd.DataFrame(one_hot_enc.transform(X_test[['initial_list_status']]),columns=one_hot_enc.get_feature_names_out())
verification_status_train = pd.DataFrame(one_hot_enc.fit_transform(X_train[['verification_status']]),columns=one_hot_enc.get_feature_names_out())
verification_status_test = pd.DataFrame(one_hot_enc.transform(X_test[['verification_status']]),columns=one_hot_enc.get_feature_names_out())

# %%
initial_list_status_train.index = X_train.index
initial_list_status_test.index = X_test.index
verification_status_train.index = X_train.index
verification_status_test.index = X_test.index

# %%
cat_cols = list(set(cat_cols) - set(['emp_length']))
X_train.drop(cat_cols,axis=1,inplace=True)
X_test.drop(cat_cols,axis=1,inplace=True)

# %%
X_train_enc = pd.concat([X_train,verification_status_train,initial_list_status_train],axis=1)
X_test_enc = pd.concat([X_test,verification_status_test,initial_list_status_test],axis=1)

# %% [markdown]
# ### 2.5 Standardization

# %%
scaler = StandardScaler()

# %%
X_train_scaled = pd.DataFrame(scaler.fit_transform(X_train),columns=X_train.columns)
X_test_scaled = pd.DataFrame(scaler.transform(X_test),columns=X_test.columns)

# %%
X_train_scaled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 665531 entries, 0 to 665530
# Data columns (total 30 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   loan_amnt                   665531 non-null  float64
#  1   int_rate                    665531 non-null  float64
#  2   annual_inc                  665531 non-null  float64
#  3   dti                         665531 non-null  float64
#  4   delinq_2yrs                 665531 non-null  float64
#  5   inq_last_6mths              665531 non-null  float64
#  6   mths_since_last_delinq      665531 non-null  float64
#  7   open_acc                    665531 non-null  float64
#  8   pub_rec                     665531 non-null  float64
#  9   revol_bal                   665531 non-null  float64
#  10  revol_util                  665531 non-null  float64
#  11  total_acc                   665531 non-null  float64
#  12  out_prncp                   665531 non-null  float64
#  13  total_pymnt                 665531 non-null  float64
#  14  total_rec_int               665531 non-null  float64
#  15  total_rec_late_fee          665531 non-null  float64
#  16  recoveries                  665531 non-null  float64
#  17  collections_12_mths_ex_med  665531 non-null  float64
#  18  acc_now_delinq              665531 non-null  float64
#  19  tot_coll_amt                665531 non-null  float64
#  20  tot_cur_bal                 665531 non-null  float64
#  21  term                        665531 non-null  float64
#  22  emp_length                  665531 non-null  float64
#  23  earliest_cr_line_D          665531 non-null  float64
#  24  last_pymnt_d_D              665531 non-null  float64
#  25  next_pymnt_d_D              665531 non-null  float64
#  26  grade_enc                   665531 non-null  float64
#  27  home_ownership_enc          665531 non-null  float64
#  28  purpose_enc                 665531 non-null  float64
#  29  addr_state_enc              665531 non-null  float64
# dtypes: float64(30)
# memory usage: 152.3 MB

# %% [markdown]
# ## 3. Modelling

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
clf = RandomForestClassifier(n_estimators=80, class_weight='balanced',random_state=10)

# %%
clf.fit(X_train_scaled,y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', n_estimators=80,
#                        random_state=10)

# %% [markdown]
# ## 4. Evaluation

# %%
y_pred = clf.predict(X_test_scaled)

# %%
print(f"recall : {recall_score(y_test,y_pred)}")
print(f"precision : {precision_score(y_test,y_pred)}")
print(f"f1 : {f1_score(y_test,y_pred)}")
# Out:
# recall : 0.9995979170139945
# precision : 0.9805011783944976
# f1 : 0.9899574600337988

# %%
from sklearn.metrics import ConfusionMatrixDisplay

# %%
ConfusionMatrixDisplay.from_estimator(
    clf, X_test_scaled, y_test,values_format='.0f')

# %% [markdown]
# By f1_score, the model seems good, but when we look at the false positive in the confusion matrix, the model is terrible. About more than half of high-risk borrowers are determined to be low-risk borrowers. This is a serious problem for LC, and it can be a big trade-off.

# %%
from xgboost import XGBClassifier
xgb_clf = XGBClassifier(n_estimators = 500,
                        learning_rate = 0.05,
                        use_label_encoder = False,
                        eval_metric = "logloss",
                        early_stopping_rounds = 5,
                        n_jobs = -1)

# %%
xgb_clf.fit(X_train_scaled,y_train,eval_set = [(X_test_scaled,y_test)])
# Out:
# [0]	validation_0-logloss:0.28803
# [1]	validation_0-logloss:0.27144
# [2]	validation_0-logloss:0.25758
# [3]	validation_0-logloss:0.24561
# [4]	validation_0-logloss:0.23508
# [5]	validation_0-logloss:0.22587
# [6]	validation_0-logloss:0.21755
# [7]	validation_0-logloss:0.20992
# [8]	validation_0-logloss:0.20287
# [9]	validation_0-logloss:0.19648
# [10]	validation_0-logloss:0.19042
# [11]	validation_0-logloss:0.18480
# [12]	validation_0-logloss:0.17952
# [13]	validation_0-logloss:0.17473
# [14]	validation_0-logloss:0.17018
# [15]	validation_0-logloss:0.16589
# [16]	validation_0-logloss:0.16195
# [17]	validation_0-logloss:0.15817
# [18]	validation_0-logloss:0.15476
# [19]	validation_0-logloss:0.15144
# [20]	validation_0-logloss:0.14831
# [21]	validation_0-logloss:0.14545
# [22]	validation_0-logloss:0.14280
# [23]	validation_0-logloss:0.14033
# [24]	validation_0-logloss:0.13813
# [25]	validation_0-logloss:0.13590
# [26]	validation_0-logloss:0.13405
# [27]	validation_0-logloss:0.13208
# [28]	validation_0-logloss:0.12993
# [29]	validation_0-logloss:0.12838
# [30]	validation_0-logloss:0.12669
# [31]	validation_0-logloss:0.12537
# [32]	validation_0-logloss:0.12405
# [33]	validation_0-logloss:0.12192
# [34]	validation_0-logloss:0.12067
# [35]	validation_0-logloss:0.11969
# [36]	validation_0-logloss:0.11871
# [37]	validation_0-logloss:0.11770
# [38]	validation_0-logloss:0.11660
# [39]	validation_0-logloss:0.11571
# [40]	validation_0-logloss:0.11475
# [41]	validation_0-logloss:0.11397
# [42]	validation_0-logloss:0.11288
# [43]	validation_0-logloss:0.11212
# [44]	validation_0-logloss:0.11121
# [45]	validation_0-logloss:0.11059
# [46]	validation_0-logloss:0.10985
# [47]	validation_0-logloss:0.10931
# [48]	validation_0-logloss:0.10861
# [49]	validation_0-logloss:0.10802
# [50]	validation_0-logloss:0.10714
# [51]	validation_0-logloss:0.10658
# [52]	validation_0-logloss:0.10608
# [53]	validation_0-logloss:0.10543
# [54]	validation_0-logloss:0.10468
# [55]	validation_0-logloss:0.10407
# [56]	validation_0-logloss:0.10352
# [57]	validation_0-logloss:0.10293
# [58]	validation_0-logloss:0.10243
# [59]	validation_0-logloss:0.10196
# [60]	validation_0-logloss:0.10158
# [61]	validation_0-logloss:0.10105
# [62]	validation_0-logloss:0.10057
# [63]	validation_0-logloss:0.10005
# [64]	validation_0-logloss:0.09962
# [65]	validation_0-logloss:0.09930
# [66]	validation_0-logloss:0.09884
# [67]	validation_0-logloss:0.09854
# [68]	validation_0-logloss:0.09814
# [69]	validation_0-logloss:0.09770
# [70]	validation_0-logloss:0.09689
# [71]	validation_0-logloss:0.09651
# [72]	validation_0-logloss:0.09537
# [73]	validation_0-logloss:0.09494
# [74]	validation_0-logloss:0.09399
# [75]	validation_0-logloss:0.09297
# [76]	validation_0-logloss:0.09238
# [77]	validation_0-logloss:0.09163
# [78]	validation_0-logloss:0.09082
# [79]	validation_0-logloss:0.09009
# [80]	validation_0-logloss:0.08955
# [81]	validation_0-logloss:0.08910
# [82]	validation_0-logloss:0.08863
# [83]	validation_0-logloss:0.08799
# [84]	validation_0-logloss:0.08741
# [85]	validation_0-logloss:0.08709
# [86]	validation_0-logloss:0.08670
# [87]	validation_0-logloss:0.08617
# [88]	validation_0-logloss:0.08529
# [89]	validation_0-logloss:0.08484
# [90]	validation_0-logloss:0.08436
# [91]	validation_0-logloss:0.08380
# [92]	validation_0-logloss:0.08339
# [93]	validation_0-logloss:0.08242
# [94]	validation_0-logloss:0.08198
# [95]	validation_0-logloss:0.08122
# [96]	validation_0-logloss:0.08026
# [97]	validation_0-logloss:0.07981
# [98]	validation_0-logloss:0.07926
# [99]	validation_0-logloss:0.07888
# [100]	validation_0-logloss:0.07797
# [101]	validation_0-logloss:0.07767
# [102]	validation_0-logloss:0.07650
# [103]	validation_0-logloss:0.07600
# [104]	validation_0-logloss:0.07565
# [105]	validation_0-logloss:0.07484
# [106]	validation_0-logloss:0.07437
# [107]	validation_0-logloss:0.07349
# [108]	validation_0-logloss:0.07332
# [109]	validation_0-logloss:0.07283
# [110]	validation_0-logloss:0.07235
# [111]	validation_0-logloss:0.07168
# [112]	validation_0-logloss:0.07128
# [113]	validation_0-logloss:0.07065
# [114]	validation_0-logloss:0.07032
# [115]	validation_0-logloss:0.06969
# [116]	validation_0-logloss:0.06926
# [117]	validation_0-logloss:0.06888
# [118]	validation_0-logloss:0.06861
# [119]	validation_0-logloss:0.06829
# [120]	validation_0-logloss:0.06799
# [121]	validation_0-logloss:0.06715
# [122]	validation_0-logloss:0.06688
# [123]	validation_0-logloss:0.06640
# [124]	validation_0-logloss:0.06620
# [125]	validation_0-logloss:0.06573
# [126]	validation_0-logloss:0.06503
# [127]	validation_0-logloss:0.06459
# [128]	validation_0-logloss:0.06398
# [129]	validation_0-logloss:0.06338
# [130]	validation_0-logloss:0.06312
# [131]	validation_0-logloss:0.06288
# [132]	validation_0-logloss:0.06275
# [133]	validation_0-logloss:0.06240
# [134]	validation_0-logloss:0.06181
# [135]	validation_0-logloss:0.06165
# [136]	validation_0-logloss:0.06145
# [137]	validation_0-logloss:0.06112
# [138]	validation_0-logloss:0.06102
# [139]	validation_0-logloss:0.06067
# [140]	validation_0-logloss:0.06047
# [141]	validation_0-logloss:0.06020
# [142]	validation_0-logloss:0.05976
# [143]	validation_0-logloss:0.05957
# [144]	validation_0-logloss:0.05941
# [145]	validation_0-logloss:0.05934
# [146]	validation_0-logloss:0.05909
# [147]	validation_0-logloss:0.05875
# [148]	validation_0-logloss:0.05861
# [149]	validation_0-logloss:0.05840
# [150]	validation_0-logloss:0.05825
# [151]	validation_0-logloss:0.05800
# [152]	validation_0-logloss:0.05778
# [153]	validation_0-logloss:0.05768
# [154]	validation_0-logloss:0.05750
# [155]	validation_0-logloss:0.05721
# [156]	validation_0-logloss:0.05718
# [157]	validation_0-logloss:0.05698
# [158]	validation_0-logloss:0.05685
# [159]	validation_0-logloss:0.05646
# [160]	validation_0-logloss:0.05616
# [161]	validation_0-logloss:0.05602
# [162]	validation_0-logloss:0.05585
# [163]	validation_0-logloss:0.05565
# [164]	validation_0-logloss:0.05539
# [165]	validation_0-logloss:0.05535
# [166]	validation_0-logloss:0.05529
# [167]	validation_0-logloss:0.05509
# [168]	validation_0-logloss:0.05498
# [169]	validation_0-logloss:0.05484
# [170]	validation_0-logloss:0.05470
# [171]	validation_0-logloss:0.05444
# [172]	validation_0-logloss:0.05429
# [173]	validation_0-logloss:0.05405
# [174]	validation_0-logloss:0.05393
# [175]	validation_0-logloss:0.05377
# [176]	validation_0-logloss:0.05357
# [177]	validation_0-logloss:0.05345
# [178]	validation_0-logloss:0.05322
# [179]	validation_0-logloss:0.05309
# [180]	validation_0-logloss:0.05299
# [181]	validation_0-logloss:0.05288
# [182]	validation_0-logloss:0.05280
# [183]	validation_0-logloss:0.05270
# [184]	validation_0-logloss:0.05261
# [185]	validation_0-logloss:0.05242
# [186]	validation_0-logloss:0.05210
# [187]	validation_0-logloss:0.05198
# [188]	validation_0-logloss:0.05181
# [189]	validation_0-logloss:0.05165
# [190]	validation_0-logloss:0.05152
# [191]	validation_0-logloss:0.05129
# [192]	validation_0-logloss:0.05117
# [193]	validation_0-logloss:0.05108
# [194]	validation_0-logloss:0.05105
# [195]	validation_0-logloss:0.05094
# [196]	validation_0-logloss:0.05083
# [197]	validation_0-logloss:0.05060
# [198]	validation_0-logloss:0.05049
# [199]	validation_0-logloss:0.05041
# [200]	validation_0-logloss:0.05032
# [201]	validation_0-logloss:0.05015
# [202]	validation_0-logloss:0.05005
# [203]	validation_0-logloss:0.04994
# [204]	validation_0-logloss:0.04989
# [205]	validation_0-logloss:0.04979
# [206]	validation_0-logloss:0.04956
# [207]	validation_0-logloss:0.04944
# [208]	validation_0-logloss:0.04931
# [209]	validation_0-logloss:0.04920
# [210]	validation_0-logloss:0.04898
# [211]	validation_0-logloss:0.04890
# [212]	validation_0-logloss:0.04882
# [213]	validation_0-logloss:0.04849
# [214]	validation_0-logloss:0.04841
# [215]	validation_0-logloss:0.04829
# [216]	validation_0-logloss:0.04808
# [217]	validation_0-logloss:0.04797
# [218]	validation_0-logloss:0.04789
# [219]	validation_0-logloss:0.04779
# [220]	validation_0-logloss:0.04759
# [221]	validation_0-logloss:0.04745
# [222]	validation_0-logloss:0.04738
# [223]	validation_0-logloss:0.04729
# [224]	validation_0-logloss:0.04727
# [225]	validation_0-logloss:0.04719
# [226]	validation_0-logloss:0.04699
# [227]	validation_0-logloss:0.04681
# [228]	validation_0-logloss:0.04675
# [229]	validation_0-logloss:0.04664
# [230]	validation_0-logloss:0.04651
# [231]	validation_0-logloss:0.04642
# [232]	validation_0-logloss:0.04640
# [233]	validation_0-logloss:0.04635
# [234]	validation_0-logloss:0.04629
# [235]	validation_0-logloss:0.04618
# [236]	validation_0-logloss:0.04610
# [237]	validation_0-logloss:0.04603
# [238]	validation_0-logloss:0.04592
# [239]	validation_0-logloss:0.04583
# [240]	validation_0-logloss:0.04572
# [241]	validation_0-logloss:0.04563
# [242]	validation_0-logloss:0.04561
# [243]	validation_0-logloss:0.04556
# [244]	validation_0-logloss:0.04535
# [245]	validation_0-logloss:0.04526
# [246]	validation_0-logloss:0.04518
# [247]	validation_0-logloss:0.04509
# [248]	validation_0-logloss:0.04506
# [249]	validation_0-logloss:0.04488
# [250]	validation_0-logloss:0.04480
# [251]	validation_0-logloss:0.04476
# [252]	validation_0-logloss:0.04458
# [253]	validation_0-logloss:0.04454
# [254]	validation_0-logloss:0.04443
# [255]	validation_0-logloss:0.04426
# [256]	validation_0-logloss:0.04425
# [257]	validation_0-logloss:0.04420
# [258]	validation_0-logloss:0.04409
# [259]	validation_0-logloss:0.04398
# [260]	validation_0-logloss:0.04392
# [261]	validation_0-logloss:0.04389
# [262]	validation_0-logloss:0.04383
# [263]	validation_0-logloss:0.04375
# [264]	validation_0-logloss:0.04370
# [265]	validation_0-logloss:0.04358
# [266]	validation_0-logloss:0.04349
# [267]	validation_0-logloss:0.04342
# [268]	validation_0-logloss:0.04328
# [269]	validation_0-logloss:0.04318
# [270]	validation_0-logloss:0.04312
# [271]	validation_0-logloss:0.04306
# [272]	validation_0-logloss:0.04303
# [273]	validation_0-logloss:0.04291
# [274]	validation_0-logloss:0.04286
# [275]	validation_0-logloss:0.04278
# [276]	validation_0-logloss:0.04272
# [277]	validation_0-logloss:0.04269
# [278]	validation_0-logloss:0.04265
# [279]	validation_0-logloss:0.04254
# [280]	validation_0-logloss:0.04252
# [281]	validation_0-logloss:0.04238
# [282]	validation_0-logloss:0.04232
# [283]	validation_0-logloss:0.04231
# [284]	validation_0-logloss:0.04223
# [285]	validation_0-logloss:0.04221
# [286]	validation_0-logloss:0.04216
# [287]	validation_0-logloss:0.04212
# [288]	validation_0-logloss:0.04204
# [289]	validation_0-logloss:0.04197
# [290]	validation_0-logloss:0.04186
# [291]	validation_0-logloss:0.04184
# [292]	validation_0-logloss:0.04176
# [293]	validation_0-logloss:0.04163
# [294]	validation_0-logloss:0.04158
# [295]	validation_0-logloss:0.04152
# [296]	validation_0-logloss:0.04146
# [297]	validation_0-logloss:0.04141
# [298]	validation_0-logloss:0.04137
# [299]	validation_0-logloss:0.04130
# [300]	validation_0-logloss:0.04127
# [301]	validation_0-logloss:0.04118
# [302]	validation_0-logloss:0.04111
# [303]	validation_0-logloss:0.04108
# [304]	validation_0-logloss:0.04102
# [305]	validation_0-logloss:0.04099
# [306]	validation_0-logloss:0.04091
# [307]	validation_0-logloss:0.04083
# [308]	validation_0-logloss:0.04078
# [309]	validation_0-logloss:0.04068
# [310]	validation_0-logloss:0.04066
# [311]	validation_0-logloss:0.04054
# [312]	validation_0-logloss:0.04050
# [313]	validation_0-logloss:0.04045
# [314]	validation_0-logloss:0.04043
# [315]	validation_0-logloss:0.04035
# [316]	validation_0-logloss:0.04029
# [317]	validation_0-logloss:0.04025
# [318]	validation_0-logloss:0.04018
# [319]	validation_0-logloss:0.04014
# [320]	validation_0-logloss:0.04012
# [321]	validation_0-logloss:0.04009
# [322]	validation_0-logloss:0.03999
# [323]	validation_0-logloss:0.03992
# [324]	validation_0-logloss:0.03990
# [325]	validation_0-logloss:0.03980
# [326]	validation_0-logloss:0.03976
# [327]	validation_0-logloss:0.03974
# [328]	validation_0-logloss:0.03972
# [329]	validation_0-logloss:0.03965
# [330]	validation_0-logloss:0.03957
# [331]	validation_0-logloss:0.03956
# [332]	validation_0-logloss:0.03953
# [333]	validation_0-logloss:0.03944
# [334]	validation_0-logloss:0.03939
# [335]	validation_0-logloss:0.03937
# [336]	validation_0-logloss:0.03931
# [337]	validation_0-logloss:0.03927
# [338]	validation_0-logloss:0.03922
# [339]	validation_0-logloss:0.03918
# [340]	validation_0-logloss:0.03912
# [341]	validation_0-logloss:0.03905
# [342]	validation_0-logloss:0.03898
# [343]	validation_0-logloss:0.03897
# [344]	validation_0-logloss:0.03895
# [345]	validation_0-logloss:0.03887
# [346]	validation_0-logloss:0.03884
# [347]	validation_0-logloss:0.03877
# [348]	validation_0-logloss:0.03874
# [349]	validation_0-logloss:0.03871
# [350]	validation_0-logloss:0.03869
# [351]	validation_0-logloss:0.03863
# [352]	validation_0-logloss:0.03856
# [353]	validation_0-logloss:0.03853
# [354]	validation_0-logloss:0.03848
# [355]	validation_0-logloss:0.03846
# [356]	validation_0-logloss:0.03839
# [357]	validation_0-logloss:0.03836
# [358]	validation_0-logloss:0.03828
# [359]	validation_0-logloss:0.03826
# [360]	validation_0-logloss:0.03824
# [361]	validation_0-logloss:0.03820
# [362]	validation_0-logloss:0.03818
# [363]	validation_0-logloss:0.03815
# [364]	validation_0-logloss:0.03810
# [365]	validation_0-logloss:0.03805
# [366]	validation_0-logloss:0.03803
# [367]	validation_0-logloss:0.03801
# [368]	validation_0-logloss:0.03798
# [369]	validation_0-logloss:0.03792
# [370]	validation_0-logloss:0.03789
# [371]	validation_0-logloss:0.03782
# [372]	validation_0-logloss:0.03780
# [373]	validation_0-logloss:0.03778
# [374]	validation_0-logloss:0.03776
# [375]	validation_0-logloss:0.03772
# [376]	validation_0-logloss:0.03770
# [377]	validation_0-logloss:0.03767
# [378]	validation_0-logloss:0.03762
# [379]	validation_0-logloss:0.03759
# [380]	validation_0-logloss:0.03757
# [381]	validation_0-logloss:0.03754
# [382]	validation_0-logloss:0.03750
# [383]	validation_0-logloss:0.03745
# [384]	validation_0-logloss:0.03741
# [385]	validation_0-logloss:0.03740
# [386]	validation_0-logloss:0.03735
# [387]	validation_0-logloss:0.03733
# [388]	validation_0-logloss:0.03728
# [389]	validation_0-logloss:0.03727
# [390]	validation_0-logloss:0.03722
# [391]	validation_0-logloss:0.03720
# [392]	validation_0-logloss:0.03718
# [393]	validation_0-logloss:0.03714
# [394]	validation_0-logloss:0.03712
# [395]	validation_0-logloss:0.03708
# [396]	validation_0-logloss:0.03707
# [397]	validation_0-logloss:0.03705
# [398]	validation_0-logloss:0.03703
# [399]	validation_0-logloss:0.03701
# [400]	validation_0-logloss:0.03699
# [401]	validation_0-logloss:0.03695
# [402]	validation_0-logloss:0.03694
# [403]	validation_0-logloss:0.03692
# [404]	validation_0-logloss:0.03690
# [405]	validation_0-logloss:0.03686
# [406]	validation_0-logloss:0.03681
# [407]	validation_0-logloss:0.03680
# [408]	validation_0-logloss:0.03677
# [409]	validation_0-logloss:0.03673
# [410]	validation_0-logloss:0.03673
# [411]	validation_0-logloss:0.03670
# [412]	validation_0-logloss:0.03667
# [413]	validation_0-logloss:0.03664
# [414]	validation_0-logloss:0.03664
# [415]	validation_0-logloss:0.03660
# [416]	validation_0-logloss:0.03657
# [417]	validation_0-logloss:0.03653
# [418]	validation_0-logloss:0.03648
# [419]	validation_0-logloss:0.03645
# [420]	validation_0-logloss:0.03644
# [421]	validation_0-logloss:0.03640
# [422]	validation_0-logloss:0.03634
# [423]	validation_0-logloss:0.03633
# [424]	validation_0-logloss:0.03630
# [425]	validation_0-logloss:0.03628
# [426]	validation_0-logloss:0.03625
# [427]	validation_0-logloss:0.03620
# [428]	validation_0-logloss:0.03617
# [429]	validation_0-logloss:0.03615
# [430]	validation_0-logloss:0.03613
# [431]	validation_0-logloss:0.03612
# [432]	validation_0-logloss:0.03611
# [433]	validation_0-logloss:0.03608
# [434]	validation_0-logloss:0.03603
# [435]	validation_0-logloss:0.03599
# [436]	validation_0-logloss:0.03597
# [437]	validation_0-logloss:0.03596
# [438]	validation_0-logloss:0.03594
# [439]	validation_0-logloss:0.03593
# [440]	validation_0-logloss:0.03592
# [441]	validation_0-logloss:0.03589
# [442]	validation_0-logloss:0.03588
# [443]	validation_0-logloss:0.03586
# [444]	validation_0-logloss:0.03585
# [445]	validation_0-logloss:0.03581
# [446]	validation_0-logloss:0.03580
# [447]	validation_0-logloss:0.03576
# [448]	validation_0-logloss:0.03574
# [449]	validation_0-logloss:0.03571
# [450]	validation_0-logloss:0.03566
# [451]	validation_0-logloss:0.03563
# [452]	validation_0-logloss:0.03562
# [453]	validation_0-logloss:0.03559
# [454]	validation_0-logloss:0.03556
# [455]	validation_0-logloss:0.03555
# [456]	validation_0-logloss:0.03552
# [457]	validation_0-logloss:0.03550
# [458]	validation_0-logloss:0.03547
# [459]	validation_0-logloss:0.03544
# [460]	validation_0-logloss:0.03543
# [461]	validation_0-logloss:0.03542
# [462]	validation_0-logloss:0.03541
# [463]	validation_0-logloss:0.03539
# [464]	validation_0-logloss:0.03538
# [465]	validation_0-logloss:0.03537
# [466]	validation_0-logloss:0.03535
# [467]	validation_0-logloss:0.03535
# [468]	validation_0-logloss:0.03534
# [469]	validation_0-logloss:0.03531
# [470]	validation_0-logloss:0.03528
# [471]	validation_0-logloss:0.03526
# [472]	validation_0-logloss:0.03526
# [473]	validation_0-logloss:0.03525
# [474]	validation_0-logloss:0.03524
# [475]	validation_0-logloss:0.03522
# [476]	validation_0-logloss:0.03519
# [477]	validation_0-logloss:0.03519
# [478]	validation_0-logloss:0.03519
# [479]	validation_0-logloss:0.03515
# [480]	validation_0-logloss:0.03515
# [481]	validation_0-logloss:0.03514
# [482]	validation_0-logloss:0.03512
# [483]	validation_0-logloss:0.03510
# [484]	validation_0-logloss:0.03507
# [485]	validation_0-logloss:0.03506
# [486]	validation_0-logloss:0.03505
# [487]	validation_0-logloss:0.03502
# [488]	validation_0-logloss:0.03499
# [489]	validation_0-logloss:0.03495
# [490]	validation_0-logloss:0.03494
# [491]	validation_0-logloss:0.03491
# [492]	validation_0-logloss:0.03490
# [493]	validation_0-logloss:0.03488
# [494]	validation_0-logloss:0.03484
# [495]	validation_0-logloss:0.03482
# [496]	validation_0-logloss:0.03480
# [497]	validation_0-logloss:0.03479
# [498]	validation_0-logloss:0.03478
# [499]	validation_0-logloss:0.03475
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=5,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=500,
#               n_jobs=-1, num_parallel_tree=None, random_state=None, ...)

# %%
y_pred_xgb = xgb_clf.predict(X_test_scaled)
print(f"recall : {recall_score(y_test,y_pred_xgb)}")
print(f"precision : {precision_score(y_test,y_pred_xgb)}")
print(f"f1 : {f1_score(y_test,y_pred_xgb)}")
# Out:
# recall : 0.9995390756014083
# precision : 0.9911554338894211
# f1 : 0.9953296012460907

# %%
ConfusionMatrixDisplay.from_estimator(
    xgb_clf, X_test_scaled, y_test,values_format='.0f')

# %% [markdown]
# ### 4.1 Over Sampling

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
ros = RandomOverSampler(random_state=10)

# %%
X_train_resampled, y_train_resampled = ros.fit_resample(X_train_scaled,y_train)

# %%
clf.fit(X_train_resampled,y_train_resampled)
# Out:
# RandomForestClassifier(class_weight='balanced', n_estimators=80,
#                        random_state=10)

# %%
y_pred_new = clf.predict(X_test_scaled)

# %%
print(f"recall : {recall_score(y_test,y_pred_new)}")
print(f"precision : {precision_score(y_test,y_pred_new)}")
print(f"f1 : {f1_score(y_test,y_pred_new)}")
# Out:
# recall : 0.9990045994370839
# precision : 0.9825846652455317
# f1 : 0.9907266025422823

# %%
ConfusionMatrixDisplay.from_estimator(
    clf, X_test_scaled, y_test,values_format='.0f')

# %% [markdown]
# We can improve the model's performance in predicting high-risk borrowers. However, in return the performance in predicting positive values is reduced. This may not sound good, but it is certainly better than classifying more high-risk borrowers as low-risk borrowers. To go further, the model can be improved to achieve greater profits. One step that might really need to be tried is a cost-sensitive classifier. A better model will certainly bring more profits to the company. Therefore, aspects that have a high impact, such as false positives in this case, need to be considered more deeply.

# %%
xgb_clf_ros = XGBClassifier(n_estimators = 500,
                        learning_rate = 0.05,
                        use_label_encoder = False,
                        eval_metric = "logloss",
                        early_stopping_rounds = 5,
                        n_jobs = -1)

xgb_clf_ros.fit(X_train_resampled,y_train_resampled,eval_set = [(X_test_scaled,y_test)])
# Out:
# [0]	validation_0-logloss:0.66453
# [1]	validation_0-logloss:0.63839
# [2]	validation_0-logloss:0.61431
# [3]	validation_0-logloss:0.59193
# [4]	validation_0-logloss:0.57131
# [5]	validation_0-logloss:0.55218
# [6]	validation_0-logloss:0.53447
# [7]	validation_0-logloss:0.51797
# [8]	validation_0-logloss:0.50260
# [9]	validation_0-logloss:0.48821
# [10]	validation_0-logloss:0.47467
# [11]	validation_0-logloss:0.46194
# [12]	validation_0-logloss:0.45014
# [13]	validation_0-logloss:0.43887
# [14]	validation_0-logloss:0.42853
# [15]	validation_0-logloss:0.41865
# [16]	validation_0-logloss:0.40945
# [17]	validation_0-logloss:0.40065
# [18]	validation_0-logloss:0.39340
# [19]	validation_0-logloss:0.38546
# [20]	validation_0-logloss:0.37763
# [21]	validation_0-logloss:0.37043
# [22]	validation_0-logloss:0.36449
# [23]	validation_0-logloss:0.35799
# [24]	validation_0-logloss:0.35271
# [25]	validation_0-logloss:0.34806
# [26]	validation_0-logloss:0.34328
# [27]	validation_0-logloss:0.33804
# [28]	validation_0-logloss:0.33447
# [29]	validation_0-logloss:0.33008
# [30]	validation_0-logloss:0.32680
# [31]	validation_0-logloss:0.32207
# [32]	validation_0-logloss:0.31863
# [33]	validation_0-logloss:0.31580
# [34]	validation_0-logloss:0.31172
# [35]	validation_0-logloss:0.30757
# [36]	validation_0-logloss:0.30452
# [37]	validation_0-logloss:0.30215
# [38]	validation_0-logloss:0.29871
# [39]	validation_0-logloss:0.29602
# [40]	validation_0-logloss:0.29382
# [41]	validation_0-logloss:0.29192
# [42]	validation_0-logloss:0.28894
# [43]	validation_0-logloss:0.28657
# [44]	validation_0-logloss:0.28491
# [45]	validation_0-logloss:0.28271
# [46]	validation_0-logloss:0.28091
# [47]	validation_0-logloss:0.27927
# [48]	validation_0-logloss:0.27714
# [49]	validation_0-logloss:0.27505
# [50]	validation_0-logloss:0.27254
# [51]	validation_0-logloss:0.27063
# [52]	validation_0-logloss:0.26887
# [53]	validation_0-logloss:0.26679
# [54]	validation_0-logloss:0.26560
# [55]	validation_0-logloss:0.26328
# [56]	validation_0-logloss:0.26165
# [57]	validation_0-logloss:0.26016
# [58]	validation_0-logloss:0.25782
# [59]	validation_0-logloss:0.25632
# [60]	validation_0-logloss:0.25450
# [61]	validation_0-logloss:0.25239
# [62]	validation_0-logloss:0.24987
# [63]	validation_0-logloss:0.24899
# [64]	validation_0-logloss:0.24685
# [65]	validation_0-logloss:0.24605
# [66]	validation_0-logloss:0.24390
# [67]	validation_0-logloss:0.24253
# [68]	validation_0-logloss:0.24121
# [69]	validation_0-logloss:0.23909
# [70]	validation_0-logloss:0.23788
# [71]	validation_0-logloss:0.23587
# [72]	validation_0-logloss:0.23458
# [73]	validation_0-logloss:0.23297
# [74]	validation_0-logloss:0.23160
# [75]	validation_0-logloss:0.23052
# [76]	validation_0-logloss:0.22945
# [77]	validation_0-logloss:0.22771
# [78]	validation_0-logloss:0.22669
# [79]	validation_0-logloss:0.22529
# [80]	validation_0-logloss:0.22408
# [81]	validation_0-logloss:0.22312
# [82]	validation_0-logloss:0.22152
# [83]	validation_0-logloss:0.22016
# [84]	validation_0-logloss:0.21903
# [85]	validation_0-logloss:0.21813
# [86]	validation_0-logloss:0.21577
# [87]	validation_0-logloss:0.21464
# [88]	validation_0-logloss:0.21309
# [89]	validation_0-logloss:0.21259
# [90]	validation_0-logloss:0.21129
# [91]	validation_0-logloss:0.21017
# [92]	validation_0-logloss:0.20816
# [93]	validation_0-logloss:0.20715
# [94]	validation_0-logloss:0.20639
# [95]	validation_0-logloss:0.20551
# [96]	validation_0-logloss:0.20492
# [97]	validation_0-logloss:0.20300
# [98]	validation_0-logloss:0.20195
# [99]	validation_0-logloss:0.20129
# [100]	validation_0-logloss:0.20027
# [101]	validation_0-logloss:0.19920
# [102]	validation_0-logloss:0.19841
# [103]	validation_0-logloss:0.19751
# [104]	validation_0-logloss:0.19663
# [105]	validation_0-logloss:0.19545
# [106]	validation_0-logloss:0.19437
# [107]	validation_0-logloss:0.19387
# [108]	validation_0-logloss:0.19249
# [109]	validation_0-logloss:0.19108
# [110]	validation_0-logloss:0.19042
# [111]	validation_0-logloss:0.18886
# [112]	validation_0-logloss:0.18789
# [113]	validation_0-logloss:0.18718
# [114]	validation_0-logloss:0.18625
# [115]	validation_0-logloss:0.18595
# [116]	validation_0-logloss:0.18504
# [117]	validation_0-logloss:0.18393
# [118]	validation_0-logloss:0.18319
# [119]	validation_0-logloss:0.18238
# [120]	validation_0-logloss:0.18168
# [121]	validation_0-logloss:0.18123
# [122]	validation_0-logloss:0.18058
# [123]	validation_0-logloss:0.18024
# [124]	validation_0-logloss:0.17958
# [125]	validation_0-logloss:0.17866
# [126]	validation_0-logloss:0.17814
# [127]	validation_0-logloss:0.17708
# [128]	validation_0-logloss:0.17669
# [129]	validation_0-logloss:0.17592
# [130]	validation_0-logloss:0.17503
# [131]	validation_0-logloss:0.17480
# [132]	validation_0-logloss:0.17355
# [133]	validation_0-logloss:0.17276
# [134]	validation_0-logloss:0.17195
# [135]	validation_0-logloss:0.17111
# [136]	validation_0-logloss:0.17056
# [137]	validation_0-logloss:0.17027
# [138]	validation_0-logloss:0.16872
# [139]	validation_0-logloss:0.16713
# [140]	validation_0-logloss:0.16636
# [141]	validation_0-logloss:0.16591
# [142]	validation_0-logloss:0.16518
# [143]	validation_0-logloss:0.16417
# [144]	validation_0-logloss:0.16387
# [145]	validation_0-logloss:0.16302
# [146]	validation_0-logloss:0.16240
# [147]	validation_0-logloss:0.16173
# [148]	validation_0-logloss:0.16128
# [149]	validation_0-logloss:0.16106
# [150]	validation_0-logloss:0.16049
# [151]	validation_0-logloss:0.15992
# [152]	validation_0-logloss:0.15932
# [153]	validation_0-logloss:0.15860
# [154]	validation_0-logloss:0.15840
# [155]	validation_0-logloss:0.15702
# [156]	validation_0-logloss:0.15643
# [157]	validation_0-logloss:0.15593
# [158]	validation_0-logloss:0.15544
# [159]	validation_0-logloss:0.15468
# [160]	validation_0-logloss:0.15447
# [161]	validation_0-logloss:0.15418
# [162]	validation_0-logloss:0.15293
# [163]	validation_0-logloss:0.15242
# [164]	validation_0-logloss:0.15196
# [165]	validation_0-logloss:0.15123
# [166]	validation_0-logloss:0.15060
# [167]	validation_0-logloss:0.15037
# [168]	validation_0-logloss:0.14951
# [169]	validation_0-logloss:0.14896
# [170]	validation_0-logloss:0.14841
# [171]	validation_0-logloss:0.14820
# [172]	validation_0-logloss:0.14705
# [173]	validation_0-logloss:0.14638
# [174]	validation_0-logloss:0.14575
# [175]	validation_0-logloss:0.14536
# [176]	validation_0-logloss:0.14492
# [177]	validation_0-logloss:0.14351
# [178]	validation_0-logloss:0.14286
# [179]	validation_0-logloss:0.14232
# [180]	validation_0-logloss:0.14134
# [181]	validation_0-logloss:0.14094
# [182]	validation_0-logloss:0.14058
# [183]	validation_0-logloss:0.14018
# [184]	validation_0-logloss:0.13889
# [185]	validation_0-logloss:0.13829
# [186]	validation_0-logloss:0.13791
# [187]	validation_0-logloss:0.13759
# [188]	validation_0-logloss:0.13728
# [189]	validation_0-logloss:0.13648
# [190]	validation_0-logloss:0.13613
# [191]	validation_0-logloss:0.13572
# [192]	validation_0-logloss:0.13550
# [193]	validation_0-logloss:0.13493
# [194]	validation_0-logloss:0.13460
# [195]	validation_0-logloss:0.13424
# [196]	validation_0-logloss:0.13403
# [197]	validation_0-logloss:0.13390
# [198]	validation_0-logloss:0.13356
# [199]	validation_0-logloss:0.13310
# [200]	validation_0-logloss:0.13223
# [201]	validation_0-logloss:0.13184
# [202]	validation_0-logloss:0.13158
# [203]	validation_0-logloss:0.13140
# [204]	validation_0-logloss:0.13104
# [205]	validation_0-logloss:0.13069
# [206]	validation_0-logloss:0.13001
# [207]	validation_0-logloss:0.12981
# [208]	validation_0-logloss:0.12947
# [209]	validation_0-logloss:0.12922
# [210]	validation_0-logloss:0.12903
# [211]	validation_0-logloss:0.12872
# [212]	validation_0-logloss:0.12822
# [213]	validation_0-logloss:0.12764
# [214]	validation_0-logloss:0.12737
# [215]	validation_0-logloss:0.12712
# [216]	validation_0-logloss:0.12686
# [217]	validation_0-logloss:0.12666
# [218]	validation_0-logloss:0.12650
# [219]	validation_0-logloss:0.12622
# [220]	validation_0-logloss:0.12584
# [221]	validation_0-logloss:0.12563
# [222]	validation_0-logloss:0.12549
# [223]	validation_0-logloss:0.12519
# [224]	validation_0-logloss:0.12495
# [225]	validation_0-logloss:0.12476
# [226]	validation_0-logloss:0.12445
# [227]	validation_0-logloss:0.12434
# [228]	validation_0-logloss:0.12423
# [229]	validation_0-logloss:0.12379
# [230]	validation_0-logloss:0.12357
# [231]	validation_0-logloss:0.12334
# [232]	validation_0-logloss:0.12318
# [233]	validation_0-logloss:0.12273
# [234]	validation_0-logloss:0.12252
# [235]	validation_0-logloss:0.12235
# [236]	validation_0-logloss:0.12214
# [237]	validation_0-logloss:0.12186
# [238]	validation_0-logloss:0.12173
# [239]	validation_0-logloss:0.12117
# [240]	validation_0-logloss:0.12092
# [241]	validation_0-logloss:0.12072
# [242]	validation_0-logloss:0.12042
# [243]	validation_0-logloss:0.12024
# [244]	validation_0-logloss:0.12003
# [245]	validation_0-logloss:0.11996
# [246]	validation_0-logloss:0.11963
# [247]	validation_0-logloss:0.11917
# [248]	validation_0-logloss:0.11909
# [249]	validation_0-logloss:0.11871
# [250]	validation_0-logloss:0.11843
# [251]	validation_0-logloss:0.11794
# [252]	validation_0-logloss:0.11765
# [253]	validation_0-logloss:0.11742
# [254]	validation_0-logloss:0.11735
# [255]	validation_0-logloss:0.11720
# [256]	validation_0-logloss:0.11702
# [257]	validation_0-logloss:0.11687
# [258]	validation_0-logloss:0.11647
# [259]	validation_0-logloss:0.11635
# [260]	validation_0-logloss:0.11598
# [261]	validation_0-logloss:0.11536
# [262]	validation_0-logloss:0.11517
# [263]	validation_0-logloss:0.11475
# [264]	validation_0-logloss:0.11458
# [265]	validation_0-logloss:0.11422
# [266]	validation_0-logloss:0.11413
# [267]	validation_0-logloss:0.11399
# [268]	validation_0-logloss:0.11375
# [269]	validation_0-logloss:0.11338
# [270]	validation_0-logloss:0.11318
# [271]	validation_0-logloss:0.11290
# [272]	validation_0-logloss:0.11259
# [273]	validation_0-logloss:0.11233
# [274]	validation_0-logloss:0.11222
# [275]	validation_0-logloss:0.11191
# [276]	validation_0-logloss:0.11176
# [277]	validation_0-logloss:0.11161
# [278]	validation_0-logloss:0.11141
# [279]	validation_0-logloss:0.11112
# [280]	validation_0-logloss:0.11100
# [281]	validation_0-logloss:0.11078
# [282]	validation_0-logloss:0.11064
# [283]	validation_0-logloss:0.11045
# [284]	validation_0-logloss:0.11036
# [285]	validation_0-logloss:0.11027
# [286]	validation_0-logloss:0.10979
# [287]	validation_0-logloss:0.10971
# [288]	validation_0-logloss:0.10940
# [289]	validation_0-logloss:0.10923
# [290]	validation_0-logloss:0.10901
# [291]	validation_0-logloss:0.10887
# [292]	validation_0-logloss:0.10868
# [293]	validation_0-logloss:0.10848
# [294]	validation_0-logloss:0.10845
# [295]	validation_0-logloss:0.10828
# [296]	validation_0-logloss:0.10793
# [297]	validation_0-logloss:0.10775
# [298]	validation_0-logloss:0.10762
# [299]	validation_0-logloss:0.10728
# [300]	validation_0-logloss:0.10720
# [301]	validation_0-logloss:0.10713
# [302]	validation_0-logloss:0.10688
# [303]	validation_0-logloss:0.10677
# [304]	validation_0-logloss:0.10652
# [305]	validation_0-logloss:0.10645
# [306]	validation_0-logloss:0.10627
# [307]	validation_0-logloss:0.10605
# [308]	validation_0-logloss:0.10595
# [309]	validation_0-logloss:0.10574
# [310]	validation_0-logloss:0.10556
# [311]	validation_0-logloss:0.10519
# [312]	validation_0-logloss:0.10496
# [313]	validation_0-logloss:0.10487
# [314]	validation_0-logloss:0.10471
# [315]	validation_0-logloss:0.10459
# [316]	validation_0-logloss:0.10446
# [317]	validation_0-logloss:0.10430
# [318]	validation_0-logloss:0.10426
# [319]	validation_0-logloss:0.10421
# [320]	validation_0-logloss:0.10414
# [321]	validation_0-logloss:0.10391
# [322]	validation_0-logloss:0.10381
# [323]	validation_0-logloss:0.10367
# [324]	validation_0-logloss:0.10359
# [325]	validation_0-logloss:0.10333
# [326]	validation_0-logloss:0.10319
# [327]	validation_0-logloss:0.10308
# [328]	validation_0-logloss:0.10297
# [329]	validation_0-logloss:0.10285
# [330]	validation_0-logloss:0.10244
# [331]	validation_0-logloss:0.10241
# [332]	validation_0-logloss:0.10208
# [333]	validation_0-logloss:0.10193
# [334]	validation_0-logloss:0.10188
# [335]	validation_0-logloss:0.10172
# [336]	validation_0-logloss:0.10162
# [337]	validation_0-logloss:0.10153
# [338]	validation_0-logloss:0.10148
# [339]	validation_0-logloss:0.10143
# [340]	validation_0-logloss:0.10122
# [341]	validation_0-logloss:0.10083
# [342]	validation_0-logloss:0.10068
# [343]	validation_0-logloss:0.10050
# [344]	validation_0-logloss:0.10035
# [345]	validation_0-logloss:0.10031
# [346]	validation_0-logloss:0.10021
# [347]	validation_0-logloss:0.10014
# [348]	validation_0-logloss:0.09997
# [349]	validation_0-logloss:0.09962
# [350]	validation_0-logloss:0.09956
# [351]	validation_0-logloss:0.09946
# [352]	validation_0-logloss:0.09930
# [353]	validation_0-logloss:0.09914
# [354]	validation_0-logloss:0.09905
# [355]	validation_0-logloss:0.09894
# [356]	validation_0-logloss:0.09884
# [357]	validation_0-logloss:0.09854
# [358]	validation_0-logloss:0.09850
# [359]	validation_0-logloss:0.09832
# [360]	validation_0-logloss:0.09807
# [361]	validation_0-logloss:0.09790
# [362]	validation_0-logloss:0.09783
# [363]	validation_0-logloss:0.09774
# [364]	validation_0-logloss:0.09764
# [365]	validation_0-logloss:0.09755
# [366]	validation_0-logloss:0.09748
# [367]	validation_0-logloss:0.09733
# [368]	validation_0-logloss:0.09725
# [369]	validation_0-logloss:0.09692
# [370]	validation_0-logloss:0.09686
# [371]	validation_0-logloss:0.09655
# [372]	validation_0-logloss:0.09653
# [373]	validation_0-logloss:0.09650
# [374]	validation_0-logloss:0.09641
# [375]	validation_0-logloss:0.09627
# [376]	validation_0-logloss:0.09621
# [377]	validation_0-logloss:0.09590
# [378]	validation_0-logloss:0.09582
# [379]	validation_0-logloss:0.09577
# [380]	validation_0-logloss:0.09567
# [381]	validation_0-logloss:0.09562
# [382]	validation_0-logloss:0.09535
# [383]	validation_0-logloss:0.09524
# [384]	validation_0-logloss:0.09508
# [385]	validation_0-logloss:0.09501
# [386]	validation_0-logloss:0.09492
# [387]	validation_0-logloss:0.09462
# [388]	validation_0-logloss:0.09453
# [389]	validation_0-logloss:0.09443
# [390]	validation_0-logloss:0.09430
# [391]	validation_0-logloss:0.09424
# [392]	validation_0-logloss:0.09416
# [393]	validation_0-logloss:0.09414
# [394]	validation_0-logloss:0.09399
# [395]	validation_0-logloss:0.09396
# [396]	validation_0-logloss:0.09379
# [397]	validation_0-logloss:0.09371
# [398]	validation_0-logloss:0.09362
# [399]	validation_0-logloss:0.09356
# [400]	validation_0-logloss:0.09351
# [401]	validation_0-logloss:0.09327
# [402]	validation_0-logloss:0.09322
# [403]	validation_0-logloss:0.09319
# [404]	validation_0-logloss:0.09305
# [405]	validation_0-logloss:0.09297
# [406]	validation_0-logloss:0.09272
# [407]	validation_0-logloss:0.09264
# [408]	validation_0-logloss:0.09255
# [409]	validation_0-logloss:0.09231
# [410]	validation_0-logloss:0.09224
# [411]	validation_0-logloss:0.09205
# [412]	validation_0-logloss:0.09184
# [413]	validation_0-logloss:0.09178
# [414]	validation_0-logloss:0.09165
# [415]	validation_0-logloss:0.09161
# [416]	validation_0-logloss:0.09151
# [417]	validation_0-logloss:0.09144
# [418]	validation_0-logloss:0.09127
# [419]	validation_0-logloss:0.09117
# [420]	validation_0-logloss:0.09110
# [421]	validation_0-logloss:0.09104
# [422]	validation_0-logloss:0.09090
# [423]	validation_0-logloss:0.09087
# [424]	validation_0-logloss:0.09079
# [425]	validation_0-logloss:0.09066
# [426]	validation_0-logloss:0.09059
# [427]	validation_0-logloss:0.09054
# [428]	validation_0-logloss:0.09041
# [429]	validation_0-logloss:0.09030
# [430]	validation_0-logloss:0.09022
# [431]	validation_0-logloss:0.09011
# [432]	validation_0-logloss:0.09006
# [433]	validation_0-logloss:0.08994
# [434]	validation_0-logloss:0.08984
# [435]	validation_0-logloss:0.08974
# [436]	validation_0-logloss:0.08958
# [437]	validation_0-logloss:0.08954
# [438]	validation_0-logloss:0.08938
# [439]	validation_0-logloss:0.08932
# [440]	validation_0-logloss:0.08926
# [441]	validation_0-logloss:0.08915
# [442]	validation_0-logloss:0.08910
# [443]	validation_0-logloss:0.08904
# [444]	validation_0-logloss:0.08885
# [445]	validation_0-logloss:0.08883
# [446]	validation_0-logloss:0.08877
# [447]	validation_0-logloss:0.08873
# [448]	validation_0-logloss:0.08870
# [449]	validation_0-logloss:0.08861
# [450]	validation_0-logloss:0.08845
# [451]	validation_0-logloss:0.08842
# [452]	validation_0-logloss:0.08835
# [453]	validation_0-logloss:0.08826
# [454]	validation_0-logloss:0.08816
# [455]	validation_0-logloss:0.08805
# [456]	validation_0-logloss:0.08802
# [457]	validation_0-logloss:0.08790
# [458]	validation_0-logloss:0.08784
# [459]	validation_0-logloss:0.08778
# [460]	validation_0-logloss:0.08764
# [461]	validation_0-logloss:0.08756
# [462]	validation_0-logloss:0.08751
# [463]	validation_0-logloss:0.08734
# [464]	validation_0-logloss:0.08729
# [465]	validation_0-logloss:0.08725
# [466]	validation_0-logloss:0.08716
# [467]	validation_0-logloss:0.08708
# [468]	validation_0-logloss:0.08697
# [469]	validation_0-logloss:0.08683
# [470]	validation_0-logloss:0.08671
# [471]	validation_0-logloss:0.08668
# [472]	validation_0-logloss:0.08650
# [473]	validation_0-logloss:0.08639
# [474]	validation_0-logloss:0.08629
# [475]	validation_0-logloss:0.08622
# [476]	validation_0-logloss:0.08616
# [477]	validation_0-logloss:0.08615
# [478]	validation_0-logloss:0.08605
# [479]	validation_0-logloss:0.08601
# [480]	validation_0-logloss:0.08594
# [481]	validation_0-logloss:0.08591
# [482]	validation_0-logloss:0.08583
# [483]	validation_0-logloss:0.08580
# [484]	validation_0-logloss:0.08572
# [485]	validation_0-logloss:0.08557
# [486]	validation_0-logloss:0.08542
# [487]	validation_0-logloss:0.08534
# [488]	validation_0-logloss:0.08527
# [489]	validation_0-logloss:0.08511
# [490]	validation_0-logloss:0.08505
# [491]	validation_0-logloss:0.08502
# [492]	validation_0-logloss:0.08498
# [493]	validation_0-logloss:0.08484
# [494]	validation_0-logloss:0.08481
# [495]	validation_0-logloss:0.08479
# [496]	validation_0-logloss:0.08475
# [497]	validation_0-logloss:0.08469
# [498]	validation_0-logloss:0.08456
# [499]	validation_0-logloss:0.08450
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=5,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=500,
#               n_jobs=-1, num_parallel_tree=None, random_state=None, ...)

# %%
y_pred_xgb = xgb_clf_ros.predict(X_test_scaled)
print(f"recall : {recall_score(y_test,y_pred_xgb)}")
print(f"precision : {precision_score(y_test,y_pred_xgb)}")
print(f"f1 : {f1_score(y_test,y_pred_xgb)}")
# Out:
# recall : 0.9863144681226648
# precision : 0.9945709411851962
# f1 : 0.9904254978667252

# %%
ConfusionMatrixDisplay.from_estimator(
    xgb_clf_ros, X_test_scaled, y_test,values_format='.0f')
