# %%
import matplotlib.pyplot as plt
import seaborn as sns

import pandas as pd
import numpy as np

# %%
df = pd.read_csv('dataset_3.csv')
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0    male  22.0                        1                        0   7.2500
# 1  female  38.0                        1                        0  71.2833
# 2  female  26.0                        0                        0   7.9250
# 3  female  35.0                        1                        0  53.1000
# 4    male  35.0                        0                        0   8.0500

# %%
df.shape
# Out:
# (887, 8)

# %%
# ###
# line plot,
# bar plot
# pie plot
# scatter plot
# histogram
# area plot
# boxplot
# heatmap
# violin plot
# tree map
# pareto plot
# swarmplot

# # ---

# %%
## important functions

# %%
plt.plot(np.linspace(1,10))
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('title')
plt.show()

# %%
plt.plot(np.linspace(1,10),'ro') # line style is changed
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('title')
plt.show()

# %%
plt.plot(df.Fare,df.Age,'go')
plt.xlabel('Indices')
plt.ylabel('Age')
plt.title('Age distribution')
plt.show()

# %% [markdown]
# ###### histogram

# %%
plt.hist(df.Survived)
plt.show()

# %%
plt.hist(df.Age)
plt.xlabel('Age')
plt.ylabel('count')
plt.title('Histogram of the age')
plt.show()

# %%
sns.distplot(df.Age)
plt.show()

# %% [markdown]
# ###### scatterplot

# %%
plt.scatter(df.Age, df.Fare)
# relationship between variables
# outliers

# %%
sns.scatterplot(df.Age, df.Fare)

# %%
# fig, ax = plt.subplots(1, 2, figsize = (20,4))
# sns.scatterplot(x= 'Age',y = 'Fare', hue='Survived', data = df[df.Survived == 1], ax = ax[0])
# sns.scatterplot(x= 'Age',y = 'Fare', hue='Survived', data = df[df.Survived == 0], ax = ax[1])

# %% [markdown]
# ###### barplot

# %%
plt.bar(['3','2','1'], [df[df.Pclass==3].Pclass.shape[0], df[df.Pclass==2].Pclass.count(), df[df.Pclass==1].Pclass.count()])
# Out:
# <BarContainer object of 3 artists>

# %%
sns.countplot(df.Pclass)

# %% [markdown]
# ###### boxplot

# %%
plt.figure(figsize = (20,4))
plt.boxplot(df.Age,vert =False )
plt.xlabel('Age')
plt.show()

# %%
df.Age.describe()
# Out:
# count    887.000000
# mean      29.471443
# std       14.121908
# min        0.420000
# 25%       20.250000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
plt.figure(figsize = (20,4))
sns.boxplot(df.Age)

# %% [markdown]
# ###### swarmplot

# %%
sns.swarmplot(df.Age)

# %% [markdown]
# ###### violineplot

# %%
sns.violinplot(df.Age)
# plt.xticks()

# %% [markdown]
# ###### heatmap

# %%
df.corr() # corr() -> pearson correlation
# [-1,1]
# [-1,-0.75], [0.75,1]
# Out:
#                          Survived    Pclass       Age  \
# Survived                 1.000000 -0.336528 -0.059665
# Pclass                  -0.336528  1.000000 -0.391492
# Age                     -0.059665 -0.391492  1.000000
# Siblings/Spouses Aboard -0.037082  0.085026 -0.297669
# Parents/Children Aboard  0.080097  0.020252 -0.193741
# Fare                     0.256179 -0.548919  0.112329
#
#                          Siblings/Spouses Aboard  Parents/Children Aboard  \
# Survived                               -0.037082                 0.080097
# Pclass                                  0.085026                 0.020252
# Age                                    -0.297669                -0.193741
# Siblings/Spouses Aboard                 1.000000                 0.414244
# Parents/Children Aboard                 0.414244                 1.000000
# Fare                                    0.158839                 0.215470
#
#                              Fare
# ...

# %%
sns.heatmap(df.corr())

# %% [markdown]
# ###### pairplot

# %%
sns.pairplot(df)

# %%
fig, ax = plt.subplots(2, 2, figsize = (20,7))
sns.boxplot(df.Age, ax = ax[0,0])
sns.distplot(df.Age, ax = ax[0,1])
sns.scatterplot(df.Age,df.Fare, ax = ax[1,0], color = 'm')
sns.violinplot(df.Age, ax = ax[1,1], color = 'c')
